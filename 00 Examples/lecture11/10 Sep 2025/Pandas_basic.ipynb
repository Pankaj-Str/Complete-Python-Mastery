# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.1

# %%
# data set 

data = ['java','python','c++','machine learning','AI']

s = pd.Series(data)
print(s)
# Out:
# 0                java
# 1              python
# 2                 c++
# 3    machine learning
# 4                  AI
# dtype: object

# %%
print(s[1])
# Out:
# python

# %%
indexx = [101,102,103,104,105]
s = pd.Series(data,index=indexx)
print(s)
# Out:
# 101                java
# 102              python
# 103                 c++
# 104    machine learning
# 105                  AI
# dtype: object

# %%
# access item from data
print(s[102])
# Out:
# python

# %%
# pd.DataFrame

data = {
    'name':['rohan','nishant','tiya','rahul','aditya'],
     'age':[23,45,66,89,34],
     'salary':[23000,56000,67000,56000,7000] 
}

df = pd.DataFrame(data)
df
# Out:
#       name  age  salary
# 0    rohan   23   23000
# 1  nishant   45   56000
# 2     tiya   66   67000
# 3    rahul   89   56000
# 4   aditya   34    7000

# %%
# export 
df.to_csv('data.csv',index=False)

# %%
data = pd.read_csv('data1.csv')
data
# Out:
#    EmployeeID FirstName LastName                  Email Department  \
# 0        1001     Alice  Johnson    alice.j@example.com         HR
# 1        1002       Bob    Smith  bob.smith@example.com         IT
# 2        1003     Carol    Davis    carol.d@example.com    Finance
# 3        1004       Dan    Brown      dan.b@example.com  Marketing
# 4        1005      Emma   Wilson     emma.w@example.com         IT
# 5        1006     Frank      Lee    frank.l@example.com      Sales
# 6        1007     Grace      Kim    grace.k@example.com         HR
# 7        1008     Henry   Miller    henry.m@example.com         IT
# 8        1009       Ivy    Lopez      ivy.l@example.com  Marketing
# 9        1010      Jack   Nguyen     jack.n@example.com    Finance
#
#                 Role  Salary    HireDate         City    Status
# 0         HR Manager   65000  12-05-2018     New York    Active
# 1  Software Engineer   78000  20-03-2019      Chicago    Active
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#    EmployeeID FirstName LastName                  Email Department  \
# 0        1001     Alice  Johnson    alice.j@example.com         HR
# 1        1002       Bob    Smith  bob.smith@example.com         IT
# 2        1003     Carol    Davis    carol.d@example.com    Finance
# 3        1004       Dan    Brown      dan.b@example.com  Marketing
# 4        1005      Emma   Wilson     emma.w@example.com         IT
# 5        1006     Frank      Lee    frank.l@example.com      Sales
# 6        1007     Grace      Kim    grace.k@example.com         HR
# 7        1008     Henry   Miller    henry.m@example.com         IT
# 8        1009       Ivy    Lopez      ivy.l@example.com  Marketing
# 9        1010      Jack   Nguyen     jack.n@example.com    Finance
#
#                 Role  Salary    HireDate         City    Status
# 0         HR Manager   65000  12-05-2018     New York    Active
# 1  Software Engineer   78000  20-03-2019      Chicago    Active
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  10 non-null     int64
#  1   FirstName   10 non-null     object
#  2   LastName    10 non-null     object
#  3   Email       10 non-null     object
#  4   Department  10 non-null     object
#  5   Role        10 non-null     object
#  6   Salary      10 non-null     int64
#  7   HireDate    10 non-null     object
#  8   City        10 non-null     object
#  9   Status      10 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 932.0+ bytes

# %%
df.describe()
# Out:
#        EmployeeID        Salary
# count    10.00000     10.000000
# mean   1005.50000  72300.000000
# std       3.02765   7087.547766
# min    1001.00000  63000.000000
# 25%    1003.25000  67250.000000
# 50%    1005.50000  71000.000000
# 75%    1007.75000  77250.000000
# max    1010.00000  85000.000000
