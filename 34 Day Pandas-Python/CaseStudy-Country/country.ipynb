# %%
import csv
import pandas as pd
# Open the CSV file
with open('world.csv', 'r') as file:
    # Create a CSV reader object
    csv_reader = csv.reader(file)
    df = pd.DataFrame(csv_reader)
    print(df)
# Out:
#               0                 1             2                      3   \
# 0        Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)
# 1    Afghanistan                60            AF                 58.10%
# 2        Albania               105            AL                 43.10%
# 3        Algeria                18            DZ                 17.40%
# 4        Andorra               164            AD                 40.00%
# ..           ...               ...           ...                    ...
# 191    Venezuela                32            VE                 24.50%
# 192      Vietnam               314            VN                 39.30%
# 193        Yemen                56            YE                 44.60%
# 194       Zambia                25            ZM                 32.10%
# 195     Zimbabwe                38            ZW                 41.90%
#
#                  4                  5           6             7   \
# 0    Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code
# 1           652,230            323,000       32.49            93
# 2            28,748              9,000       11.78           355
# 3         2,381,741            317,000       24.28           213
# 4               468                            7.2           376
# ..              ...                ...         ...           ...
# 191         912,050            343,000       17.88            58
# 192         331,210            522,000       16.75            84
# 193         527,968             40,000       30.45           967
# 194         752,618             16,000       36.19           260
# 195         390,757             51,000       30.68           263
#
#                      8              9   ...                                25  \
# 0    Capital/Major City  Co2-Emissions  ...  Out of pocket health expenditure
# 1                 Kabul          8,672  ...                            78.40%
# 2                Tirana          4,536  ...                            56.90%
# 3               Algiers        150,006  ...                            28.10%
# 4      Andorra la Vella            469  ...                            36.40%
# ..                  ...            ...  ...                               ...
# 191             Caracas        164,175  ...                            45.80%
# 192               Hanoi        192,668  ...                            43.50%
# 193               Sanaa         10,609  ...                            81.00%
# 194              Lusaka          5,141  ...                            27.50%
# 195              Harare         10,983  ...                            25.80%
#
#                           26          27  \
# 0    Physicians per thousand  Population
# 1                       0.28  38,041,754
# 2                        1.2   2,854,191
# 3                       1.72  43,053,054
# 4                       3.33      77,142
# ..                       ...         ...
# 191                     1.92  28,515,829
# 192                     0.82  96,462,106
# 193                     0.31  29,161,922
# 194                     1.19  17,861,030
# 195                     0.21  14,645,468
#
#                                             28               29  \
# 0    Population: Labor force participation (%)  Tax revenue (%)
# 1                                       48.90%            9.30%
# 2                                       55.70%           18.60%
# 3                                       41.20%           37.20%
# 4
# ..                                         ...              ...
# 191                                     59.70%
# 192                                     77.40%           19.10%
# 193                                     38.00%
# 194                                     74.60%           16.20%
# 195                                     83.10%           20.70%
#
#                  30                 31                32          33  \
# 0    Total tax rate  Unemployment rate  Urban_population    Latitude
# 1            71.40%             11.12%         9,797,273    33.93911
# 2            36.60%             12.33%         1,747,593   41.153332
# 3            66.10%             11.70%        31,510,100   28.033886
# 4                                                 67,873   42.506285
# ..              ...                ...               ...         ...
# 191          73.30%              8.80%        25,162,368     6.42375
# 192          37.60%              2.01%        35,332,140   14.058324
# 193          26.60%             12.91%        10,869,523   15.552727
# 194          15.60%             11.43%         7,871,713  -13.133897
# 195          31.60%              4.95%         4,717,305  -19.015438
#
#              34
# 0     Longitude
# 1     67.709953
# 2     20.168331
# 3      1.659626
# 4      1.521801
# ..          ...
# 191   -66.58973
# 192  108.277199
# 193   48.516388
# 194   27.849332
# 195   29.154857
#
# [196 rows x 35 columns]

# %%
Country = []
Capital = []
Official_language = []
with open('world.csv', 'r') as file:
    # Create a CSV reader object
    csv_reader = csv.reader(file)
    for i in csv_reader:
        #print(i)
        # access single column 
        Country0 = i[0]
        Capital8 = i[8]
        Official_language23 = i[22]
        #print(col1)
        Country.append(Country0)
        Capital.append(Capital8)
        Official_language.append(Official_language23)

#print(Country)
#print(Capital)
#print(Official_language)

size = len(Country)

for i in range(size):
  print(f'{Country[i]} | {Capital[i]} | {Official_language[i]}')
# Out:
# Country | Capital/Major City | Maternal mortality ratio
# Afghanistan | Kabul | 638
# Albania | Tirana | 15
# Algeria | Algiers | 112
# Andorra | Andorra la Vella |
# Angola | Luanda | 241
# Antigua and Barbuda | St. John's, Saint John | 42
# Argentina | Buenos Aires | 39
# Armenia | Yerevan | 26
# Australia | Canberra | 6
# Austria | Vienna | 5
# Azerbaijan | Baku | 26
# The Bahamas | Nassau, Bahamas | 70
# Bahrain | Manama | 14
# Bangladesh | Dhaka | 173
# Barbados | Bridgetown | 27
# Belarus | Minsk | 2
# Belgium | City of Brussels | 5
# Belize | Belmopan | 36
# Benin | Porto-Novo | 397
# Bhutan | Thimphu | 183
# Bolivia | Sucre | 155
# Bosnia and Herzegovina | Sarajevo | 10
# Botswana | Gaborone | 144
# Brazil | Brasï¿½ï¿½ï¿½ | 60
# Brunei | Bandar Seri Begawan | 31
# Bulgaria | Sofia | 10
# Burkina Faso | Ouagadougou | 320
# Burundi | Bujumbura | 548
# Ivory Coast | Yamoussoukro | 617
# Cape Verde | Praia | 58
# Cambodia | Phnom Penh | 160
# Cameroon | Yaoundï¿½ | 529
# Canada | Ottawa | 10
# Central African Republic | Bangui | 829
# Chad | N'Djamena | 1140
# Chile | Santiago | 13
# China | Beijing | 29
# Colombia | Bogotï¿½ | 83
# Comoros | Moroni, Comoros | 273
# Republic of the Congo | Brazzaville | 378
# Costa Rica | San Josï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ | 27
# Croatia | Zagreb | 8
# Cuba | Havana | 36
# Cyprus | Nicosia | 6
# Czech Republic | Prague | 3
# Democratic Republic of the Congo | Kinshasa | 473
# Denmark | Copenhagen | 4
# Djibouti | Djibouti City | 248
# Dominica | Roseau |
# Dominican Republic | Santo Domingo | 95
# Ecuador | Quito | 59
# Egypt | Cairo | 37
# El Salvador | San Salvador | 46
# Equatorial Guinea | Malabo | 301
# Eritrea | Asmara | 480
# Estonia | Tallinn | 9
# Eswatini | Mbabane |
# Ethiopia | Addis Ababa | 401
# Fiji | Suva | 34
# Finland | Helsinki | 3
# France | Paris | 8
# Gabon | Libreville | 252
# The Gambia | Banjul | 597
# Georgia | Tbilisi | 25
# Germany | Berlin | 7
# Ghana | Accra | 308
# Greece | Athens | 3
# Grenada | St. George's, Grenada | 25
# Guatemala | Guatemala City | 95
# Guinea | Conakry | 576
# Guinea-Bissau | Bissau | 667
# Guyana | Georgetown, Guyana | 169
# Haiti | Port-au-Prince | 480
# Vatican City | Vatican City |
# Honduras | Tegucigalpa | 65
# Hungary | Budapest | 12
# Iceland | Reykjavï¿½ï¿½ | 4
# India | New Delhi | 145
# Indonesia | Jakarta | 177
# Iran | Tehran | 16
# Iraq | Baghdad | 79
# Republic of Ireland | Dublin | 5
# Israel | Jerusalem | 3
# Italy | Rome | 2
# Jamaica | Kingston, Jamaica | 80
# Japan | Tokyo | 5
# Jordan | Amman | 46
# Kazakhstan | Astana | 10
# Kenya | Nairobi | 342
# Kiribati | South Tarawa | 92
# Kuwait | Kuwait City | 12
# Kyrgyzstan | Bishkek | 60
# Laos | Vientiane | 185
# Latvia | Riga | 19
# Lebanon | Beirut | 29
# Lesotho | Maseru | 544
# Liberia | Monrovia | 661
# Libya |  | 72
# Liechtenstein | Vaduz |
# Lithuania | Vilnius | 8
# Luxembourg | Luxembourg City | 5
# Madagascar | Antananarivo | 335
# Malawi | Lilongwe | 349
# Malaysia | Kuala Lumpur | 29
# Maldives | Malï¿½ | 53
# Mali | Bamako | 562
# Malta | Valletta | 6
# Marshall Islands | Majuro |
# Mauritania | Nouakchott | 766
# Mauritius | Port Louis | 61
# Mexico | Mexico City | 33
# Federated States of Micronesia | Palikir | 88
# Moldova | Chiï¿½ï¿½ï¿½ï¿½ | 19
# Monaco | Monaco City |
# Mongolia | Ulaanbaatar | 45
# Montenegro | Podgorica | 6
# Morocco | Rabat | 70
# Mozambique | Maputo | 289
# Myanmar | Naypyidaw | 250
# Namibia | Windhoek | 195
# Nauru | Yaren District |
# Nepal | Kathmandu | 186
# Netherlands | Amsterdam | 5
# New Zealand | Wellington | 9
# Nicaragua | Managua | 98
# Niger | Niamey | 509
# Nigeria | Abuja | 917
# North Korea | Pyongyang | 89
# North Macedonia | Skopje |
# Norway | Oslo | 2
# Oman | Muscat | 19
# Pakistan | Islamabad | 140
# Palau | Ngerulmud |
# Palestinian National Authority |  |
# Panama | Panama City | 52
# Papua New Guinea | Port Moresby | 145
# Paraguay | Asunciï¿½ï¿½ | 129
# Peru | Lima | 88
# Philippines | Manila | 121
# Poland | Warsaw | 2
# Portugal | Lisbon | 8
# Qatar | Doha | 9
# Romania | Bucharest | 19
# Russia | Moscow | 17
# Rwanda | Kigali | 248
# Saint Kitts and Nevis | Basseterre |
# Saint Lucia | Castries | 117
# Saint Vincent and the Grenadines | Kingstown | 68
# Samoa | Apia | 43
# San Marino | City of San Marino |
# Sï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ | Sï¿½ï¿½ï¿½ï¿½ | 130
# Saudi Arabia | Riyadh | 17
# Senegal | Dakar | 315
# Serbia | Belgrade | 12
# Seychelles | Victoria, Seychelles | 53
# Sierra Leone | Freetown | 1120
# Singapore |  | 8
# Slovakia | Bratislava | 5
# Slovenia | Ljubljana | 7
# Solomon Islands | Honiara | 104
# Somalia | Mogadishu | 829
# South Africa | Pretoria | 119
# South Korea | Seoul | 11
# South Sudan | Juba | 1150
# Spain | Madrid | 4
# Sri Lanka | Colombo | 36
# Sudan | Khartoum | 295
# Suriname | Paramaribo | 120
# Sweden | Stockholm | 4
# Switzerland | Bern | 5
# Syria | Damascus | 31
# Tajikistan | Dushanbe | 17
# Tanzania | Dodoma | 524
# Thailand | Bangkok | 37
# East Timor | Dili | 142
# Togo | Lomï¿½ | 396
# Tonga | Nukuï¿½ï¿½ï¿½ï¿½ | 52
# Trinidad and Tobago | Port of Spain | 67
# Tunisia | Tunis | 43
# Turkey | Ankara | 17
# Turkmenistan | Ashgabat | 7
# Tuvalu | Funafuti |
# Uganda | Kampala | 375
# Ukraine | Kyiv | 19
# United Arab Emirates | Abu Dhabi | 3
# United Kingdom | London | 7
# United States | Washington, D.C. | 19
# Uruguay | Montevideo | 17
# Uzbekistan | Tashkent | 29
# Vanuatu | Port Vila | 72
# Venezuela | Caracas | 125
# Vietnam | Hanoi | 43
# Yemen | Sanaa | 164
# Zambia | Lusaka | 213
# Zimbabwe | Harare | 458
