# %%
# install lib
# %pip install matplotlib pandas yfinance

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# %%
stock = yf.download("RELIANCE.NS", start="2023-01-01", end="2024-01-01")
print(stock.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2023-01-02  1175.889648  1177.304802  1163.244669  1164.066352     5316175
# 2023-01-03  1167.284668  1174.565828  1163.062148  1170.936659     7658932
# 2023-01-04  1149.709595  1169.110728  1147.632506  1167.261851     9264891
# 2023-01-05  1147.655396  1157.858149  1143.067616  1151.969321    13637099
# 2023-01-06  1158.086304  1163.130627  1149.595501  1153.407240     6349597

# %%
# Line Chart – Stock Closing Price
plt.figure()
plt.plot(stock['Close'])
plt.title("Reliance Stock Closing Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.show()

# %%
# Moving Average (Trend Analysis)
stock['MA50'] = stock['Close'].rolling(window=50).mean()

plt.figure()
plt.plot(stock['Close'], label="Close Price")
plt.plot(stock['MA50'], label="50-Day MA")
plt.legend()
plt.title("Moving Average Analysis")
plt.show()

# %%
# 5. Bar Chart – Volume Analysis
plt.figure()
plt.bar(stock.index, stock['Volume']['RELIANCE.NS'])
plt.title("Daily Trading Volume")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
# 6. Candlestick Chart (Advanced)
# %pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mplfinance) (3.10.7)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mplfinance) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib->mplfinance) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib->mplfinance) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib->mplfinance) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib->mplfinance) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/pankajchouhan/Library/Python/3.14/lib/python/site-packages (from matplotlib->mplfinance) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib->mplfinance) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib->mplfinance) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pankajchouhan/Library/Python/3.14/lib/python/site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/pankajchouhan/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas->mplfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas->mplfinance) (2025.2)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import mplfinance as mpf

# Step 1: Flatten columns
stock.columns = stock.columns.droplevel(1)

# Step 2: Convert to float
stock = stock.astype(float)

# Step 3: Plot
mpf.plot(stock, type='candle', volume=True, title="Reliance Candlestick Chart")

# %%
stocks = yf.download(["RELIANCE.NS", "TCS.NS"], start="2023-01-01", end="2024-01-01")

plt.figure()
plt.plot(stocks['Close']['RELIANCE.NS'], label="Reliance")
plt.plot(stocks['Close']['TCS.NS'], label="TCS")
plt.legend()
plt.title("Stock Comparison")
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
stock['Daily Return'] = stock['Close'].pct_change()

plt.figure()
plt.plot(stock['Daily Return'])
plt.title("Daily Returns")
plt.show()

# %%
plt.figure()
plt.hist(stock['Daily Return'].dropna(), bins=50)
plt.title("Return Distribution")
plt.show()
