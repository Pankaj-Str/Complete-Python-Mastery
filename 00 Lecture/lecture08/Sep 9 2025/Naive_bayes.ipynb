# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import CategoricalNB
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
data = {
    'Flu': ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No'],
    'COVID': ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No'],
    'Fever': ['Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No']
}

# %%
# convert to df 
df = pd.DataFrame(data)
#print(df)

# %%
# label Encoder yes/no  to 1/0
le_flu = LabelEncoder()
le_covid = LabelEncoder()
le_fever = LabelEncoder()

# %%
df['Flu'] = le_flu.fit_transform(df['Flu'])
df['COVID'] = le_covid.fit_transform(df['COVID'])
df['Fever'] = le_fever.fit_transform(df['Fever'])

# %%
# features flu , covid (x) target (y) fever
X = df[['Flu','COVID']].values
y = df['Fever'].values

# %%
# train the CategoricalNB model
model = CategoricalNB(alpha=1.0)
model.fit(X,y)
# Out:
# CategoricalNB()

# %%
# predict data (flu = yes , covid = yes)
new_data = np.array([[le_flu.transform(['Yes'])[0],le_covid.transform(['Yes'])[0]]]) # [1,1]
prediction = model.predict(new_data)
prediction_proba = model.predict_proba(new_data)

# %%
# decode 
prediction_label = le_fever.inverse_transform(prediction)[0]
proba_yes = prediction_proba[0][1]
proba_no = prediction_proba[0][0]

# %%
print(f'prediction fever {prediction_label}')
print(f'Probability of fever = Yes {proba_yes:.3f}')
print(f'Probability of fever = No {proba_no:.3f}')
# Out:
# prediction fever Yes
# Probability of fever = Yes 0.963
# Probability of fever = No 0.037
