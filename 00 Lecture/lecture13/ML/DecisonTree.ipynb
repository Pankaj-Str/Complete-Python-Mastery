# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier , plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
data ={
    "Study_Hours":[1,2,3,4,5,6,7,8],
    "Attendance":[60,65,75,80,85,90,95,98],
    "Result":["Fail","Fail","Fail","Pass","Pass","Pass","Pass","Pass"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Study_Hours  Attendance Result
# 0            1          60   Fail
# 1            2          65   Fail
# 2            3          75   Fail
# 3            4          80   Pass
# 4            5          85   Pass
# 5            6          90   Pass
# 6            7          95   Pass
# 7            8          98   Pass

# %%
X = df[['Study_Hours','Attendance']]
y = df['Result']

# %%
# train Decision Tree Model
model = DecisionTreeClassifier(criterion="gini",max_depth=3,random_state)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt_tree(model,feature_names=['Study_Hours','Attendance'],
         class_names=["Fail","Pass"],
         filled=True,
         rounded="True")
plt.title("DecisionTreeClassifier")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt_tree(model,feature_names=['Study_Hours','Attendance'],
#       2          class_names=["Fail","Pass"],
#       3          filled=True,
#       4          rounded="True")
#       5 plt.title("DecisionTreeClassifier")
#       6 plt.show()
#
# NameError: name 'plt_tree' is not defined
