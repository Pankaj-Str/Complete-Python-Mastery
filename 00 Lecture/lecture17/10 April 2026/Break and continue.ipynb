# %%
for i in range(20):
    if i == 5:
        break
    else:
        print(i)

# %%
for i in range(20):
    if i == 5:
        #continue 
        pass
    else:
        print(i)

# %%
for i in range(20):
    if i < 5:
        continue
    else:
        print(i)
