# %%
"python"

# %%
data = "python"
data

# %%
data = 'codeswithpankaj'
print(data[12])
print(data[4:15])
print(data[-3])

# %%
data1 = "abc"
data2 = " abd"

print(data1 == data2)
print(data1 is data2)

# %%
data = 'codeswithpankaj'
for i in data:
    print(i)

# %%
# 1. upper() converts the string to uppercas
print(data.upper())
# 2. lower() converts the string to lowercase
print(data.lower())
# 3. partition() returns a tuple
print(data.partition('a'))
# 4. replace() replaces substring inside
print(data.replace("pankaj","python"))

# %%
# 5. find() returns the index of first occurrence of substring
print(data.find('j'))
# 6. rstrip() removes trailing characters
data = "hello        "
print(data,"welcome")
print(data.rstrip(),"welcome")
# 7. split() splits string from left
data = "c o d e s w i t h p a n k a j"
print(data.split(" "))

# %%
# 8. startswith() checks if string starts with the specified string
print(data.startswith("c"))

# %%
# 9. isnumeric() checks numeric characters
data = "90"
print(data.isnumeric())
# 10. index() returns index of substring
data = "python"
print(data.index("t"))

# %%
# format()

name = "joy"
age = 80
height = 5.6

print("my name is {0} and age {1} or height {2} ".format(name,age,height))

# %%
print(f"my name is {name} and age {age}")
