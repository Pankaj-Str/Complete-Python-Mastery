# %%
data = 89,
print(data)
print(type(data))
# Out:
# (89,)
# <class 'tuple'>

# %%
data = ()
print(data)
print(type(data))
# Out:
# ()
# <class 'tuple'>

# %%
data = (34,45,55)
print(type(data))
# Out:
# <class 'tuple'>

# %%
data = (89,)
print(type(data))
# Out:
# <class 'tuple'>

# %%
data = [23,34,34]
my_t = (data,)
print(type(data))
print(type(my_t))

# 2nd way

my_1 = tuple(data)
print(type(my_1))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'tuple'>

# %%
data = [34,45,56,78,89,89,89,89]
print(data[2])
print(data[1:4])
# print(data[1:5])
# Out:
# 56
# [45, 56, 78]

# %%
# count()
print(data.count(89))
# index()
print(data.index(45))
# +
print(data+[45,56,55])
# x
d = data*3
print(type(d))
# Out:
# 4
# 1
# [34, 45, 56, 78, 89, 89, 89, 89, 45, 56, 55]
# <class 'list'>
