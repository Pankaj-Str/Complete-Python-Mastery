# %%
# basic function

def get_info():
    print("Welcome to CWPC")
    print("Welcome to Python")
    print("Welcome to ML")

# %%
# call funciton 
get_info()

# %%
# for i in range(10):
#     get_info()

# %%
# function with arg
def get_user_info(name,age):
    print(f'your name is {name}')
    print(f'your age is {age}')
    print("--------------------")

# %%
get_user_info("rupali",22)
get_user_info("joy",22)

# %%
# example - 
def bill(price,gst):
    print('----------bill-----------')
    print(f'price = {price}₹')
    print(f'gst = {gst}%')
    gst_amount = price*gst/100
    print(f'GST amount = {gst_amount}₹')
    total = price+gst_amount
    print(f'Total = {total}₹')
    print('------------------------------')

# %%
bill(1200,18)
bill(3500,9)
bill(4500,2)
bill(85000,21)
# Out:
# ----------bill-----------
# price = 1200₹
# gst = 18%
# GST amount = 216.0₹
# Total = 1416.0₹
# ------------------------------
# ----------bill-----------
# price = 3500₹
# gst = 9%
# GST amount = 315.0₹
# Total = 3815.0₹
# ------------------------------
# ----------bill-----------
# price = 4500₹
# gst = 2%
# GST amount = 90.0₹
# Total = 4590.0₹
# ------------------------------
# ----------bill-----------
# price = 85000₹
# gst = 21%
# GST amount = 17850.0₹
# Total = 102850.0₹
# ------------------------------

# %%
# return type function 
def get_number():
    return 100

# %%
print(get_number()+900)

# %%
# parameter with return 

def add(a,b):
    x = a + b
    return x

# %%
print(add(45,89))

# %%
number = add(80,45)
print(number + 900)

# %%
# arg 
# example - 
def bill(price=1200,gst=18,qty=2):
    print('----------bill-----------')
    print(f'price = {price}₹')
    print(f'QTY = {qty}₹')
    print(f'price + QTY = {price*qty}₹')
    print(f'gst = {gst}%')
    gst_amount = price*gst/100
    print(f'GST amount = {gst_amount}₹')
    total = price+gst_amount
    print(f'Total = {total}₹')
    print('------------------------------')

# %%
bill(1200,18)
bill(1200,18,10)
bill()
