# %%
import numpy as np
from scipy.stats import skew

# %%
data = np.array([10,20,15,17,18,19,23,25,56,78,90])

# %%
skews = skew(data)
print(skews)
# Out:
# 1.1865000242281374

# %%
import matplotlib.pyplot as plt
plt.hist(data,bins=5)
plt.show()
