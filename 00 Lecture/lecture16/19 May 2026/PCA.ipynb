# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
iris = load_iris()
X = iris.data
y = iris.target

print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
scaler = StandardScaler()
x_std = scaler.fit_transform(X)

# %%
# PCA
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_std)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.72962445 0.22850762]

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=y, cmap='viridis',s=100)
plt.ylabel('PC1')
plt.xlabel('PC2')
plt.title('PCA')
plt.grid(True)
plt.show()

# %%
import pandas as pd

data = {
    "math" : [90,85,92,95,88],
    "science" : [91,86,89,93,96],
    "english" : [70,65,68,72,75]
}

df = pd.DataFrame(data)
# df

scaler = StandardScaler()
scaler_data = scaler.fit_transform(df)

pca = PCA(n_components=2)

pc = pca.fit_transform(scaler_data)

pca_df = pd.DataFrame(
    pc,
    columns=['pc1','pc2']
)
print(pca_df)ith

print(pca.explained_variance_ratio_)
# Out:
#             pc1           pc2
# 0  7.202613e-16 -3.033749e-16
# 1 -2.483198e+00 -5.470346e-01
# 2 -5.373927e-01  8.635345e-01
# 3  1.335194e+00  1.030575e+00
# 4  1.685396e+00 -1.347075e+00
# [0.73855767 0.26144233]
