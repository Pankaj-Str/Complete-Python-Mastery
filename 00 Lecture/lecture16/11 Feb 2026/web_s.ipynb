# %%
# %pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (4.13.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install requests beautifulsoup4
import requests
from bs4 import BeautifulSoup
#url = "https://codeswithpankaj.com/"
url = "https://codeswithpankaj.com/free-tutorials/"

res = requests.get(url)

soup = BeautifulSoup(res.text,"html.parser")

title = soup.title.text
print(title)

heading = soup.find_all("a")

for i in heading:
    print(i.text)
# Out:
# Free Tutorials - Codes With Pankaj
#
# 		Skip to content
#
#
# 					Codes With Pankaj
#
#
# Search
#
#
#
# Home
# All Courses
# About Us
# Free Tutorials
# Contact
# Blogs
#
#
# 					Codes With Pankaj
#
# Home
# All Courses
# About Us
# Free Tutorials
# Contact
# Blogs
# View More
# C Programming
# Java SE (Core JAVA)
# Python
# SQL
# Front-end Development
# Python Interview Questions
# R Programming
# Node.js
# DSA – JAVA
# DSA – C++
# DSA – Python
# Django
# Java Interview Questions
# Express JS
# Spring
# Servlet
# C Interview Questions
# React.js
# MongoDB
# C++
# JavaScript
# AngularJS
# Complete Data Science
# Complete Machine Learning
# Complete Deep Learning
# Prime Membership
# Python Lists
# Pandas DataFrames
# Mastering NumPy
# Python Pandas — DataFrame
# Python Pandas Series
# Python Sets
# Object-Oriented Programming (OOP) Concepts in Python
# Python Dictionaries
# Using Python Pandas with Excel Sheets
# Data Visualization with Matplotlib in Python
# NumPy Random
# Implementing Binary Search Algorithm in Python
# Building a Sudoku Game in Python with Tkinter
# Understanding Python Functions
# Pandas read_csv() with Examples
# Merging, Joining, Concatenating, and Comparing DataFrames
# Case Study : Analyzing Sales Performance Using Pandas
# Visualizing Share Market Data with Python and Matplotlib
# Python-Pandas Operations for Working with Data
# Django Models & Database Tutorial
# Mastering Django Forms (Add/View Data)
# CRUD: Create, Retrieve, Update, Delete
# MySQL Views
# SQL Joins
# Database Constraints
# Data Manipulation in SQL: INSERT, UPDATE, DELETE, and MERGE
# SQL Table
# SQL Database Basics
# 10 Best AI Tools
# 10 Unconventional Free Tools for Turbocharged Productivity
# Import in R: From CSV to Databases
# Mastering R Arrays
# R Vectors
# Ajax Live Data Search using jQuery, PHP, MySQL
# PHP MySQL CRUD Application
# Insert Data into a MySQL Table using Spring Data JPA
# The JSP CRUD Operation App
# Java Multithreading
# Building a Login and Logout System with Java Servlets
# Building a Todo List with Servlet
# Java Lambda Expressions
# Node.js CRUD with MySQL
# JavaScript Shorthand Techniques for Efficient and Readable Code
# SciPy’s ndimage Module
# Unlocking the Power of SciPy
# Mastering Matrix Operations with Sparse Matrices in Python
# DBSCAN Clustering Tutorial for Beginners
# K-Means Clustering Tutorial for Beginners
# 14 Must-Know Python Pandas Operations for Working with Data – A Beginner’s Guide by Pankaj Chouhan
# Visualizing Share Market Data with Python and Matplotlib – A Step-by-Step Guide
# Seaborn Data Visualization with the Titanic Dataset by Codes With Pankaj
# Understanding Measures of Central Tendency in Data Science
# Understanding Measures of Dispersion in Data Science
# Understanding Measure of Association in Machine Learning – A Comprehensive Beginner’s Guide
# Understanding Skewness in Machine Learning – A Beginner’s Guide with Python Example
# Probability Basics in Machine Learning – A Chill Guide for Beginners
# Mastering Exploratory Data Analysis (EDA) in Python
# Linear Regression in Machine Learning with Python – A Beginner’s Guide to OLS
# Linear Regression with SGD in Python
# Feature Scaling: Normalization and Standardization
# Understanding Linear Regression with Pankaj Chouhan
# Logistic Regression in Machine Learning – A Super Easy Guide for Beginners
# A Beginner’s Guide to Decision Trees in Machine Learning
# Understanding Random Forests – A Beginner to Pro Guide
# KNN (K-Nearest Neighbors) Algorithm – A Beginner-Friendly Guide
# Data SET
# R Programming PDF
# Python Programming PDF
# Data Science Info
