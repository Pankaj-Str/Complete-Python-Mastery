# %%
data = (45,)
print(type(data))

# %%
data = 45,
print(type(data))

# %%
data = (45,65,56,78,78,90,78)
print(type(data))

# %%
print(data[2])

# %%
print(data.count(78))

# %%
print(data.index(56))
