# %%
import datetime as dt

print(dt.datetime.today())
print(dt.datetime.now())

# %%
from datetime import date

print(date.today())
print(date.today().year)
print(date.today().day)
print(date.today().month)

# %%
d = dt.datetime.now().time()
print(d)
print(d.hour)
print(d.minute)
print(d.second)
print(d.microsecond*1000)
# Out:
# 20:47:03.477143
# 20
# 47
# 3
# 477143000

# %%
# Create a date object
date_obj = dt.date(2024, 8, 5)
print("Date object:", date_obj)
# Out:
# Date object: 2024-08-05

# %%
# Create a time object
time_obj = dt.time(14, 30, 45)
print("Time object:", time_obj)
# Out:
# Time object: 14:30:45

# %%
# datetime_obj = datetime.datetime(2024, 8, 5, 14, 30, 45)
# print("Datetime object:", datetime_obj)
