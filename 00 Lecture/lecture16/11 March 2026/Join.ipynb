# %%
import pandas as pd


students = {
    'studentID':[101,102,103,104,108],
    'name':['Rupali','Joy','Bob','Charlie','Diana'],
    'age':[23,45,67,89,12],
}

result = {
    'studentID':[101,102,103,107,109],
    'subject':['maths','java','c++','go','ruby'],
    'score':[56,78,56,90,20]
}

# %%
students = pd.DataFrame(students)
students

# %%
result = pd.DataFrame(result)
result

# %%
# pd.merge()
left_merge = pd.merge(students,result,on='studentID',how='left')
left_merge

# %%
right_merge = pd.merge(students,result,on='studentID',how='right')
right_merge

# %%
outer_merge = pd.merge(students,result,on='studentID',how='outer')
outer_merge

# %%
data1 = pd.read_csv("credit_card_transactions.csv")
data1.head()

# %%
data2 = pd.read_csv("customer_details.csv")
data2.head()

# %%
print(data1.shape)
print(data2.shape)

# %%
new_data = pd.merge(data1,data2,on='Customer_ID',how='outer')
new_data.head()

# %%
print(data1.shape)
print(data2.shape)

print(new_data.shape)

# %%
print(new_data.isnull().sum())
