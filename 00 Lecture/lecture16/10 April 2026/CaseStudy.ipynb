# %%
# https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data
# https://archive.ics.uci.edu/dataset/10/automobile

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# theme
sns.set_style("whitegrid")
plt.rcParams['figure.figsize']=(10,6)

# %%
# load dataset 
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

columns = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration",
           "num-of-doors", "body-style", "drive-wheels", "engine-location", "wheel-base",
           "length", "width", "height", "curb-weight", "engine-type", "num-of-cylinders",
           "engine-size", "fuel-system", "bore", "stroke", "compression-ratio",
           "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"]

df = pd.read_csv(url,header=None,names=columns,na_values='?')
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       2 url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
#       4 columns = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration",
#       5            "num-of-doors", "body-style", "drive-wheels", "engine-location", "wheel-base",
#       6            "length", "width", "height", "curb-weight", "engine-type", "num-of-cylinders",
#       7            "engine-size", "fuel-system", "bore", "stroke", "compression-ratio",
#       8            "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"]
# ---> 10 df = pd.read_csv(url,header=None,names=columns,na_values='?')
#      11 df.head()
#
# ...

# %%
df.shape

# %%
# check column name 
df.columns.to_list()

# %%
# check info
df.info()

# %%
# summary 
# df.describe(include='all')
df.describe() # only numbers

# %%
# count of missing values 
df.isnull().sum()

# %%
df.dtypes

# %%
# count of missing values 
df.isnull().sum()

# %%
# delete 
df = df.dropna(subset=['price'])

# %%
# count of missing values 
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
import pandas as pd
import numpy as np

data = {
    'symboling': [3, 3, 1, 2, 2, 1, 0, 0, -1, -1],
    'normalized-losses': [np.nan, 164, 158, np.nan, 158, np.nan, 91, 93, 104, 103],
    'make': ['alfa-romero', 'alfa-romero', 'alfa-romero', 'audi', 'audi', 'audi', 'bmw', 'bmw', 'bmw', 'bmw'],
    'fuel-type': ['gas', 'gas', 'gas', 'gas', 'gas', 'gas', 'gas', 'gas', 'gas', 'gas'],
    'aspiration': ['std', 'std', 'std', 'std', 'std', 'turbo', 'std', 'std', 'std', 'std'],
    'num-of-doors': ['two', 'two', 'two', 'four', 'four', 'two', 'two', 'four', 'two', 'four'],
    'body-style': ['convertible', 'convertible', 'hatchback', 'sedan', 'sedan', 'sedan', 'sedan', 'sedan', 'sedan', 'sedan'],
    'drive-wheels': ['rwd', 'rwd', 'rwd', 'fwd', '4wd', 'fwd', 'rwd', 'rwd', 'rwd', 'rwd'],
    'engine-location': ['front', 'front', 'front', 'front', 'front', 'front', 'front', 'front', 'front', 'front'],
    'wheel-base': [88.6, 88.6, 94.5, 99.8, 99.4, 99.8, 101.2, 101.2, 103.5, 110.0],
    'length': [168.8, 168.8, 171.2, 176.6, 176.6, 177.3, 176.8, 176.8, 183.1, 188.8],
    'width': [64.1, 64.1, 65.5, 66.2, 66.4, 66.3, 64.8, 64.8, 66.9, 67.3],
    'height': [48.8, 48.8, 52.4, 54.3, 54.3, 53.1, 54.3, 54.3, 53.1, 54.1],
    'curb-weight': [2548, 2548, 2823, 2337, 2824, 2507, 2844, 2954, 3086, 3086],
    'engine-type': ['dohc', 'dohc', 'ohcv', 'ohc', 'ohc', 'ohc', 'ohc', 'ohc', 'ohc', 'ohc'],
    'num-of-cylinders': ['four', 'four', 'six', 'four', 'five', 'five', 'six', 'six', 'six', 'six'],
    'engine-size': [130, 130, 152, 109, 136, 136, 152, 164, 164, 164],
    'fuel-system': ['mpfi', 'mpfi', 'mpfi', 'mpfi', 'mpfi', 'mpfi', 'mpfi', 'mpfi', 'mpfi', 'mpfi'],
    'bore': [3.47, 3.47, 2.68, 3.19, 3.19, 3.19, 2.68, 3.31, 3.31, 3.31],
    'stroke': [2.68, 2.68, 3.47, 3.40, 3.40, 3.40, 3.47, 3.19, 3.19, 3.19],
    'compression-ratio': [9.0, 9.0, 9.0, 10.0, 8.0, 8.5, 8.8, 9.0, 9.0, 9.0],
    'horsepower': [111, 111, 154, 102, 115, 110, 140, 160, 300, 158],
    'peak-rpm': [5000, 5000, 5000, 5500, 5500, 5500, 4800, 5500, 5500, 5500],
    'city-mpg': [21, 21, 19, 24, 18, 19, 23, 23, 21, 21],
    'highway-mpg': [27, 27, 26, 30, 22, 25, 29, 31, 29, 28],
    'price': [13495, 16500, 16500, 13950, 17450, 15250, 17710, 18920, 23875, np.nan]
}

df = pd.DataFrame(data)
df.to_csv("auto_mobile.csv")

# %%
df.head() # show top 5 row
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3              164.0  alfa-romero       gas        std
# 2          1              158.0  alfa-romero       gas        std
# 3          2                NaN         audi       gas        std
# 4          2              158.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# show info 
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          10 non-null     int64
#  1   normalized-losses  7 non-null      float64
#  2   make               10 non-null     object
#  3   fuel-type          10 non-null     object
#  4   aspiration         10 non-null     object
#  5   num-of-doors       10 non-null     object
#  6   body-style         10 non-null     object
#  7   drive-wheels       10 non-null     object
#  8   engine-location    10 non-null     object
#  9   wheel-base         10 non-null     float64
#  10  length             10 non-null     float64
#  11  width              10 non-null     float64
#  12  height             10 non-null     float64
#  13  curb-weight        10 non-null     int64
#  14  engine-type        10 non-null     object
#  15  num-of-cylinders   10 non-null     object
# ...

# %%
# summary
df.describe()
# Out:
#        symboling  normalized-losses  wheel-base      length     width  \
# count  10.000000           7.000000   10.000000   10.000000  10.00000
# mean    1.000000         124.428571   98.660000  176.480000  65.64000
# std     1.490712          33.669260    6.564077    6.167622   1.14717
# min    -1.000000          91.000000   88.600000  168.800000  64.10000
# 25%     0.000000          98.000000   95.725000  172.550000  64.80000
# 50%     1.000000         104.000000   99.800000  176.700000  65.85000
# 75%     2.000000         158.000000  101.200000  177.175000  66.37500
# max     3.000000         164.000000  110.000000  188.800000  67.30000
#
#          height  curb-weight  engine-size       bore     stroke  \
# count  10.00000    10.000000    10.000000  10.000000  10.000000
# mean   52.75000  2755.700000   143.700000   3.180000   3.207000
# std     2.18594   257.757444    18.475509   0.282686   0.299334
# min    48.80000  2337.000000   109.000000   2.680000   2.680000
# ...

# %%
# check the null values 
# df.isna().sum()
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    3
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                1
# dtype: int64

# %%
# fill null values 

# normalized-losses
mean_norm = df['normalized-losses'].mean()
df['normalized-losses'] = df['normalized-losses'].fillna(mean_norm)

# %%
# check null values 
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# m_price = df['price'].mediam()
df['price'] = df['price'].fillna(100)

# %%
# check data missing value 
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3         124.428571  alfa-romero       gas        std
# 1          3         164.000000  alfa-romero       gas        std
# 2          1         158.000000  alfa-romero       gas        std
# 3          2         124.428571         audi       gas        std
# 4          2         158.000000         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# make
# fuel-type
# num-of-doors
# aspiration
# body-style
# drive-wheels
# engine-location
# engine-type
# num-of-cylinders
# fuel-system

data = ['make','fuel-type','num-of-doors','aspiration','body-style','drive-wheels','engine-location','engine-type','num-of-cylinders','fuel-system']

for col in data:
    print(col + ' -> ',df[col].unique())
# Out:
# make ->  ['alfa-romero' 'audi' 'bmw']
# fuel-type ->  ['gas']
# num-of-doors ->  ['two' 'four']
# aspiration ->  ['std' 'turbo']
# body-style ->  ['convertible' 'hatchback' 'sedan']
# drive-wheels ->  ['rwd' 'fwd' '4wd']
# engine-location ->  ['front']
# engine-type ->  ['dohc' 'ohcv' 'ohc']
# num-of-cylinders ->  ['four' 'six' 'five']
# fuel-system ->  ['mpfi']

# %%
df['avg_mpg'] = (df['city-mpg']+df['highway-mpg'])/2

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3         124.428571  alfa-romero       gas        std
# 1          3         164.000000  alfa-romero       gas        std
# 2          1         158.000000  alfa-romero       gas        std
# 3          2         124.428571         audi       gas        std
# 4          2         158.000000         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
# 1 Distribution of price 
sns.histplot(df['price'],kde=True,color='blue')
plt.title("Distribution of price")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
sns.boxplot(x = df['price'])
plt.title("Distribution of price")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(data=df,y="make",order=df['make'].value_counts().index,palette='viridis',hue=df['make'])
plt.title("Distribution of price")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'avg_mpg'],
#       dtype='object')

# %%
# Engine size vs price 
sns.scatterplot(
    data=df,
    x="engine-size",
    y='price',
    hue='make',
    size='curb-weight',
    alpha=0.7)
plt.title("Engine Size vs Price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()
