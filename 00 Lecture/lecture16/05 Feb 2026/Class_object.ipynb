# %%
class Bank:
    def info():
        print("Rahul - ")
        print("HDFC Bank - ")        
    def amount():
        print("1300/-")

# %%
# create a object
my_bank = Bank
my_bank.amount()
my_bank.info()
# Out:
# 1300/-

# %%
Bank.amount()
# Out:
# 1300/-
