# %%
import pandas as pd

# Sample sales data
data = {
    'Order_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Date': ['2024-01-05', '2024-01-10', '2024-01-15', '2024-02-01', '2024-02-05',
             '2024-02-10', '2024-03-01', '2024-03-05', '2024-03-10', '2024-01-20'],
    'Product': ['Laptop', 'Mouse', 'Keyboard', 'Laptop', 'Phone', 
                'Tablet', 'Mouse', 'Keyboard', 'Phone', 'Laptop'],
    'Category': ['Electronics', 'Accessories', 'Accessories', 'Electronics', 'Electronics',
                 'Electronics', 'Accessories', 'Accessories', 'Electronics', 'Electronics'],
    'Sales': [75000, 1200, 2500, 80000, 45000, 30000, 1500, 2800, 42000, 72000],
    'Quantity': [1, 5, 3, 1, 2, 3, 4, 2, 1, 2],
    'City': ['Mumbai', 'Delhi', 'Bangalore', 'Mumbai', 'Delhi', 
             'Bangalore', 'Mumbai', 'Delhi', 'Bangalore', 'Mumbai']
}

df = pd.DataFrame(data)
# df_temp.to_csv('sales_data.csv', index=False)

# %%
# Question 1 - Total Sales by city 
city_total = df.groupby('City')['Sales'].sum()
print(city_total)
# Out:
# City
# Bangalore     74500
# Delhi         49000
# Mumbai       228500
# Name: Sales, dtype: int64

# %%
# Question 2 - Averange Quantity by Category
avg_qty = df.groupby('Category')['Quantity'].mean().round(2)
print(avg_qty)
# Out:
# Category
# Accessories    3.50
# Electronics    1.67
# Name: Quantity, dtype: float64

# %%
# Question 3 - (Sales by city and Category) Group by two columns (city + Category)
t_g = df.groupby(['City','Category'])['Sales'].sum()
print(t_g)
# Out:
# City       Category
# Bangalore  Accessories      2500
#            Electronics     72000
# Delhi      Accessories      4000
#            Electronics     45000
# Mumbai     Accessories      1500
#            Electronics    227000
# Name: Sales, dtype: int64

# %%
# Question 4 - Count number of order per city
order_count = df.groupby('City').count()
print(order_count)

order_count1 = df.groupby('City').size()
print(order_count1)

order_count2 = df.groupby('City')['Order_ID'].count()
print(order_count2)
# Out:
#            Order_ID  Date  Product  Category  Sales  Quantity
# City
# Bangalore         3     3        3         3      3         3
# Delhi             3     3        3         3      3         3
# Mumbai            4     4        4         4      4         4
# City
# Bangalore    3
# Delhi        3
# Mumbai       4
# dtype: int64
# City
# Bangalore    3
# Delhi        3
# Mumbai       4
# Name: Order_ID, dtype: int64

# %%
# Question 5 - Sales -> sum , mean , max (city)
#              Quantity -> sum (city)

result = df.groupby('City').agg(
    {
        'Sales':['sum','mean','max'],
        'Quantity':'sum'
    }
).round(2)

print(result)
# Out:
#             Sales                  Quantity
#               sum      mean    max      sum
# City
# Bangalore   74500  24833.33  42000        7
# Delhi       49000  16333.33  45000        9
# Mumbai     228500  57125.00  80000        8

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Pankaj-Str/Complete-Python-Mastery/refs/heads/main/53%20DataSet/online_retail_sales_Large.csv")

# %%
data(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data(10)
#
# TypeError: 'DataFrame' object is not callable
