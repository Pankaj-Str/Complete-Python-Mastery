# %%
data = ()
print(data)

# check the type
print(type(data))
# Out:
# ()
# <class 'tuple'>

# %%
data = (21,22,23,24,25)
print(data)
# check the type
print(type(data))
# Out:
# (21, 22, 23, 24, 25)
# <class 'tuple'>

# %%
#my_list = [22,23,24,25,26]

tuple_data = ([22,23,24,25,26],(34,33))
print(tuple_data)
print(type(tuple_data))
# Out:
# ([22, 23, 24, 25, 26], (34, 33))
# <class 'tuple'>

# %%
# single tuple 
data = (90,)
print(data)
print(type(data))
# Out:
# (90,)
# <class 'tuple'>

# %%
# access item from tuple 
data = (23,24,25,26,27,28,19)
print(data[3])
print(data[-3])
print(data[3:5])
# Out:
# 26
# 27
# (26, 27)

# %%
print(data+(90,80,70))
# Out:
# (23, 24, 25, 26, 27, 28, 19, 90, 80, 70)

# %%
print(data*3)
# Out:
# (23, 24, 25, 26, 27, 28, 19, 23, 24, 25, 26, 27, 28, 19, 23, 24, 25, 26, 27, 28, 19)

# %%
print(data.index(26))
# Out:
# 3

# %%
data = (23, 24, 25, 26, 27, 28, 19, 23, 24, 25, 26, 27, 28, 19, 23, 24, 25, 26, 27, 28, 19)
print(data.count(23))
# Out:
# 3

# %%
for i in data:
    print(i)
# Out:
# 23
# 24
# 25
# 26
# 27
# 28
# 19
# 23
# 24
# 25
# 26
# 27
# 28
# 19
# 23
# 24
# 25
# 26
# 27
# 28
# 19
