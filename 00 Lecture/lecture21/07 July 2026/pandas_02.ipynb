# %%
import pandas as pd

data = {
    'Name':['Nishant','Joy','Sejal','Aryan','Anita','Ayushi'],
    'Age':[12,13,14,15,16,17],
    'City':['Mumbai','Pune','Goa','Jaipur','bhuj','Surat']
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age    City
# 0  Nishant   12  Mumbai
# 1      Joy   13    Pune
# 2    Sejal   14     Goa
# 3    Aryan   15  Jaipur
# 4    Anita   16    bhuj
# 5   Ayushi   17   Surat

# %%
# print top 2 record 
df.head(2)
# Out:
#       Name  Age    City
# 0  Nishant   12  Mumbai
# 1      Joy   13    Pune

# %%
# print top 5 
df.head()
# Out:
#       Name  Age    City
# 0  Nishant   12  Mumbai
# 1      Joy   13    Pune
# 2    Sejal   14     Goa
# 3    Aryan   15  Jaipur
# 4    Anita   16    bhuj

# %%
# print last 5 
df.tail(2)
# Out:
#      Name  Age   City
# 4   Anita   16   bhuj
# 5  Ayushi   17  Surat

# %%
# print info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   City    6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
# numeric summary 
df.describe()
# Out:
#              Age
# count   6.000000
# mean   14.500000
# std     1.870829
# min    12.000000
# 25%    13.250000
# 50%    14.500000
# 75%    15.750000
# max    17.000000

# %%
# datatype 
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
# create shape 
df.shape
# Out:
# (6, 3)

# %%
# print all columns name 
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
# print single columns data 
print(df['Name'])
# Out:
# 0    Nishant
# 1        Joy
# 2      Sejal
# 3      Aryan
# 4      Anita
# 5     Ayushi
# Name: Name, dtype: object

# %%
# print 2 columns
print(df[['Age','Name']])
# Out:
#    Age     Name
# 0   12  Nishant
# 1   13      Joy
# 2   14    Sejal
# 3   15    Aryan
# 4   16    Anita
# 5   17   Ayushi

# %%
# rows 
df.iloc[1] # by position
# Out:
# Name     Joy
# Age       13
# City    Pune
# Name: 1, dtype: object

# %%
# label 
df.loc[1] # default index
# Out:
# Name     Joy
# Age       13
# City    Pune
# Name: 1, dtype: object

# %%
# slice row 
df.iloc[1:3]
# Out:
#     Name  Age  City
# 1    Joy   13  Pune
# 2  Sejal   14   Goa

# %%
# add new columns 
df['Salary'] = [23000,78000,89000,67000,56000,90000]
df
# Out:
#       Name  Age    City  Salary
# 0  Nishant   12  Mumbai   23000
# 1      Joy   13    Pune   78000
# 2    Sejal   14     Goa   89000
# 3    Aryan   15  Jaipur   67000
# 4    Anita   16    bhuj   56000
# 5   Ayushi   17   Surat   90000

# %%
# basic Statistics 
# print average age 
print(df['Age'].mean())
# Out:
# 14.5

# %%
# max salary 
print(df['Salary'].max())
# Out:
# 90000

# %%
# total salary 
print(df['Salary'].sum())
# Out:
# 403000

# %%
# export CSV
df.to_csv("data.csv")
