# %%
# %pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\comp\appdata\roaming\python\python313\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: requests>=2.31 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (6.32.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\comp\appdata\roaming\python\python313\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\comp\appdata\roaming\python\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\comp\appdata\roaming\python\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\comp\appdata\roaming\python\python313\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\comp\appdata\roaming\python\python313\site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: pycparser in c:\users\comp\appdata\roaming\python\python313\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\comp\appdata\roaming\python\python313\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\comp\appdata\roaming\python\python313\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\comp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\comp\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\comp\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\comp\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

ticker = "AAPL"
start_date = "2023-01-01"
end_date = "2025-03-01"

stock_data = yf.download(ticker,start=start_date,end=end_date)
stock_data.to_csv("TCS_Data.csv")
print(stock_data.head())
# Out:
# C:\Users\comp\AppData\Local\Temp\ipykernel_232\1281448683.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_data = yf.download(ticker,start=start_date,end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.330635  129.079551  122.443150  128.468178  112117500
# 2023-01-04  124.602707  126.870724  123.340509  125.125335   89113600
# 2023-01-05  123.281342  125.993097  123.024963  125.361998   80962700
# 2023-01-06  127.817368  128.478048  123.153152  124.257579   87754700
# 2023-01-09  128.340012  131.554685  128.083633  128.655569   70790800

# %%
print(stock_data.shape)
print(stock_data.describe())
# Out:
# (541, 5)
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   541.000000  541.000000  541.000000  541.000000  5.410000e+02
# mean    191.839817  193.409742  189.989132  191.567869  5.778049e+07
# std      29.812169   30.046096   29.478977   29.813718  2.467663e+07
# min     123.281342  125.993097  122.443150  124.257579  2.323470e+07
# 25%     171.389206  172.424840  169.577727  170.945615  4.464920e+07
# 50%     186.047668  187.324795  184.975929  186.272965  5.245640e+07
# 75%     221.688263  224.196596  219.354043  221.578772  6.475140e+07
# max     258.103729  259.179926  256.718662  257.276679  3.186799e+08

# %%
stock_data.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
plt.Figure(figsize=(12,6))
plt.plot(stock_data.index,stock_data['Close'],label="Closing Price",color="blue")
plt.title("... AAPl Closing Price ...")
plt.xlabel('Date',fontsize=12)
plt.ylabel("Price ",fontsize=12)
plt.grid()
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
