# %%
import tax_basic as t

prduct_price = 4500
gst = 18

final_price = t.gst(prduct_price,gst)

print("this is my gst amount = ",final_price)

print()

# %%
from cwpc_pkg import Bank as b

b.Bank.Bank_info()

# 2nd way to print 

mybank = b.Bank

mybank.Bank_info()
