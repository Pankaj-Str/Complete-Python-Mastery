# %%
# %pip install qrcode[pil]
# Out:
# Collecting qrcode[pil]
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pillow>=9.1.0 in /usr/local/lib/python3.12/dist-packages (from qrcode[pil]) (11.3.0)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2

# %%
import qrcode

# Data you want to encode (URL, text, WiFi, etc.)
data = "https://codeswithpankaj.com"   # Change this to anything

# Generate and save QR code
img = qrcode.make(data)
img.save("my_qrcode.png")

print("QR Code generated successfully!")
# Out:
# QR Code generated successfully!

# %%
# %pip install pymupdf pillow
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.28.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Downloading pymupdf-1.28.0-cp310-abi3-manylinux_2_28_x86_64.whl (25.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.7/25.7 MB 47.5 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.28.0

# %%
import fitz  # PyMuPDF
import os

def pdf_to_images(pdf_path, output_folder="pdf_images", dpi=300):
    os.makedirs(output_folder, exist_ok=True)

    doc = fitz.open(pdf_path)
    print(f"Converting {len(doc)} pages to images...")

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)

        # Higher dpi = better quality (300 is good, 600 for very high quality)
        pix = page.get_pixmap(dpi=dpi, alpha=True)   # alpha=True for transparency in PNG

        output_path = os.path.join(output_folder, f"page_{page_num+1:03d}.png")
        pix.save(output_path)

        print(f"Saved: {output_path}")

    doc.close()
    print("Conversion completed!")

# Usage
pdf_to_images("Tuple.pdf")
# Out:
# Converting 16 pages to images...
# Saved: pdf_images/page_001.png
# Saved: pdf_images/page_002.png
# Saved: pdf_images/page_003.png
# Saved: pdf_images/page_004.png
# Saved: pdf_images/page_005.png
# Saved: pdf_images/page_006.png
# Saved: pdf_images/page_007.png
# Saved: pdf_images/page_008.png
# Saved: pdf_images/page_009.png
# Saved: pdf_images/page_010.png
# Saved: pdf_images/page_011.png
# Saved: pdf_images/page_012.png
# Saved: pdf_images/page_013.png
# Saved: pdf_images/page_014.png
# Saved: pdf_images/page_015.png
# Saved: pdf_images/page_016.png
# Conversion completed!

# %%
# %pip install pypdf

# read a PDF file in Python
# Out:
# Collecting pypdf
#   Downloading pypdf-6.14.2-py3-none-any.whl.metadata (7.2 kB)
# Downloading pypdf-6.14.2-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 15.5 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-6.14.2

# %%
from pypdf import PdfReader

# Open the PDF file
reader = PdfReader("Tuple.pdf")   # replace with your PDF path

# Print number of pages
print(f"Number of pages: {len(reader.pages)}")

# Extract and print text from all pages
text = ""
for page in reader.pages:
    text += page.extract_text() + "\n\n"

print(text)   # or save to a .txt file
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 16 0 (offset 0)
# Number of pages: 16
# { Python }
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
# Introduction
# •Getting Start
# •Variable and Literals
# •Input and output
# •Type conversion
# Decision Making &
# Loop
# •Boolean Expression
# •If …else statement
# •While loop
# •For loop
# •Break and continue
# •Pass
# •Control ﬂow Example
# Functions
# •Function
# •Variable scope and literals
# •Function arguments
# •Anonymous function
# •Recursion
#
# Learning Path with Pankaj Chouhan
# Collection and
# Data type
# •List
# •Tuples
# •String
# •Sets
# •Dictionary
# Modules and Files
# •Modules
# •Files
# •Directory
# Exceptions handling
# •Exception
# •Exception handling
# •Custom Exception
#
# Learning Path with Pankaj Chouhan
# Object - Oriented
# Programming
# •Class and Object
# •Constructors
# •Inheritance
# •NameSpaces
# Advance Topic
# •Iterators
# •Generatores
# •Closures
# •Decorators
# •Python @Property
#
# Tuple
# { Collection Data Type }
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
#
#
# Learning Path with Pankaj Chouhan
