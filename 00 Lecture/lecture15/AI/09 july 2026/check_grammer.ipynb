# %%
# %pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
from textblob import TextBlob

def check_grammar_textblob(text):
  blob=TextBlob(text)
  corrected = blob.correct() # fixed spelling + basic grammer

  print("Orignal text : ",text)
  print("Corrected text : ",corrected)
  print("Any change ? : ",str(corrected) != text)
  return str(corrected)

# %%
text = "this sentance have grammer errar . i goes to schhol yesterday"
check_grammar_textblob(text)
# Out:
# Orignal text :  this sentance have grammer errar . i goes to schhol yesterday
# Corrected text :  this sentence have grammar error . i goes to school yesterday
# Any change ? :  True
# 'this sentence have grammar error . i goes to school yesterday'

# %%
# %pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.9.0-py3-none-any.whl.metadata (9.3 kB)
# Downloading pyspellchecker-0.9.0-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 74.3 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.9.0

# %%
from spellchecker import SpellChecker

def spell_checker(text):
    spell = SpellChecker()
    words = text.split()

    misspelled = spell.unknown(words)

    print("Original:", text)

    if not misspelled:
        print("✅ No spelling mistakes detected!")
        return text

    print("\nSpelling Issues Found:")
    for word in misspelled:
        correction = spell.correction(word)
        print(f"• '{word}' → Suggested: '{correction}'")

    # Auto-correct the whole text
    corrected = " ".join([spell.correction(word) or word for word in words])
    print("\nFully Corrected:", corrected)
    return corrected

# Test
spell_checker("this sentance have grammer errar . i goes to schhol yesterday")
# Out:
# Original: this sentance have grammer errar . i goes to schhol yesterday
#
# Spelling Issues Found:
# • 'errar' → Suggested: 'error'
# • 'grammer' → Suggested: 'grammar'
# • 'sentance' → Suggested: 'sentence'
# • 'schhol' → Suggested: 'school'
#
# Fully Corrected: this sentence have grammar error . i goes to school yesterday
# 'this sentence have grammar error . i goes to school yesterday'

# %%
# %pip install happytransformer
# Out:
# Collecting happytransformer
#   Downloading happytransformer-3.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (from happytransformer) (2.11.0+cpu)
# Requirement already satisfied: tqdm>=4.43 in /usr/local/lib/python3.12/dist-packages (from happytransformer) (4.67.3)
# Collecting transformers<5.0.0,>=4.46.0 (from happytransformer)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
# Collecting datasets<3.0.0,>=2.15.0 (from happytransformer)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from happytransformer) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from happytransformer) (5.29.6)
# Requirement already satisfied: accelerate<2.0.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from happytransformer) (1.14.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from happytransformer) (0.22.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from happytransformer) (0.28.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.3.0->happytransformer) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.3.0->happytransformer) (26.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.3.0->happytransformer) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.3.0->happytransformer) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.3.0->happytransformer) (1.20.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.3.0->happytransformer) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (3.29.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (3.7.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (0.70.16)
# Collecting fsspec<=2024.6.1,>=2023.1.0 (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.15.0->happytransformer)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0,>=2.15.0->happytransformer) (3.14.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->happytransformer) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->happytransformer) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->happytransformer) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->happytransformer) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->happytransformer) (3.1.6)
# Collecting huggingface_hub>=0.21.0 (from accelerate<2.0.0,>=1.3.0->happytransformer)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.46.0->happytransformer) (2025.11.3)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb->happytransformer) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->happytransformer) (3.1.50)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->happytransformer) (4.10.0)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb->happytransformer) (2.13.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->happytransformer) (2.63.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.15.0->happytransformer) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.15.0->happytransformer) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.15.0->happytransformer) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.15.0->happytransformer) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.15.0->happytransformer) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.15.0->happytransformer) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0,>=2.15.0->happytransformer) (1.24.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->happytransformer) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate<2.0.0,>=1.3.0->happytransformer) (1.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb->happytransformer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb->happytransformer) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb->happytransformer) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.15.0->happytransformer) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.15.0->happytransformer) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.15.0->happytransformer) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.15.0->happytransformer) (2026.6.17)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2->happytransformer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2->happytransformer) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<3.0.0,>=2.15.0->happytransformer) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<3.0.0,>=2.15.0->happytransformer) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<3.0.0,>=2.15.0->happytransformer) (2026.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->happytransformer) (5.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets<3.0.0,>=2.15.0->happytransformer) (1.17.0)
# Downloading happytransformer-3.0.1-py3-none-any.whl (25 kB)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 18.0 MB/s eta 0:00:00
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 92.8 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 11.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 35.6 MB/s eta 0:00:00
# Installing collected packages: fsspec, huggingface_hub, transformers, datasets, happytransformer
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.20.1
#     Uninstalling huggingface_hub-1.20.1:
#       Successfully uninstalled huggingface_hub-1.20.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.12.1
#     Uninstalling transformers-5.12.1:
#       Successfully uninstalled transformers-5.12.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 6.19.0 requires huggingface-hub<2.0,>=1.2.0, but you have huggingface-hub 0.36.2 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.6.1 which is incompatible.
# Successfully installed datasets-2.21.0 fsspec-2024.6.1 happytransformer-3.0.1 huggingface_hub-0.36.2 transformers-4.57.6

# %%
from happytransformer import HappyTextToText, TTSettings

def ai_grammar_fix(text):
    happy_tt = HappyTextToText("T5", "vennify/t5-base-grammar-correction")

    settings = TTSettings(num_beams=5, min_length=1, max_length=200)

    result = happy_tt.generate_text("grammar: " + text, args=settings)

    print("Original :", text)
    print("Corrected:", result.text)
    return result.text

# First run will download the model (~800MB), so be patient
ai_grammar_fix("this sentance have grammer errar . i goes to schhol yesterday")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# WARNING:happytransformer.happy_transformer:num_beams is deprecated and will have no effect in version 4.0.0
# Device set to use cpu
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Original : this sentance have grammer errar . i goes to schhol yesterday
# Corrected: This sentance has a grammererrar . i went to school yesterday.
# 'This sentance has a grammererrar . i went to school yesterday.'
