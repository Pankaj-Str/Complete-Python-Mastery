# %%
# os -> file , folders ,path , environment variables, etc
# sys -> interact with the Python runtime environment (agruments, exit codes, path, etc)

# %%
import os
import sys

# Get current working directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: /Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025

# %%
# change directory
print("before changing:", os.getcwd())

# change the folder to parent directory
os.chdir('/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data')
print("after changing:", os.getcwd())
# Out:
# before changing: /Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025
# after changing: /Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data

# %%
path = '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01'
items = os.listdir(path)
# print("Items in directory:", items)

for names in items :
    print("-",names)
# Out:
# - 03 Oct 2025
# - 09 Oct 2025
# - .DS_Store
# - 14 Oct 2025
# - 25 Nov 2025
# - 13 Oct 2025
# - 27 Oct 2025
# - 11 Nov 2025
# - 18 Oct 2025
# - 06 Nov 2025
# - 07 Nov 2025
# - 31 Oct 2025
# - 1 Dec 2025
# - 14 Nov 2025
# - 29 Oct 2025
# - 28 Oct 2025
# - 20 Nov 2025
# - 16 Oct 2025
# - 03 Nov 2025
# - 04 Nov 2025
# - 07 Oct 2025
# - 06 Oct 2025
# - 12 Nov 2025
# - 18 Nov 2025
# - 19 Nov 2025
# - 27 Nov 2025
# - 10 Oct 2025

# %%
# create a new folder 
path = '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025'
folder_name = 'Data_Files'

if not os.path.exists(folder_name):
    os.mkdir(folder_name)
    print(f"Folder '{folder_name}' created successfully.")
else:
    print(f"Folder '{folder_name}' already exists.")
# Out:
# Folder 'Data_Files' created successfully.

# %%
nested_folders = 'cwpc/python_tutorial/data'
os.makedirs(nested_folders, exist_ok=True)
print(f"Nested folders '{nested_folders}' created successfully.")
# Out:
# Nested folders 'cwpc/python_tutorial/data' created successfully.

# %%
# check if path is file or directory
file_path = '/Users/pankajchouhan/github/Complete-Python-Mastery1/'

if os.path.exists(file_path):
   if os.path.isfile(file_path):
       print(f"{file_path} is a file.")
   elif os.path.isdir(file_path):
       print(f"{file_path} is a directory.")
else:
   print(f"{file_path} does not exist.")
# Out:
# /Users/pankajchouhan/github/Complete-Python-Mastery1/ does not exist.

# %%
# delete file and folder
file = '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/data.txt'

if os.path.exists(file):
    os.remove(file)
    print(f"File '{file}' has been deleted.")
else:
    print(f"File '{file}' does not exist.")
# Out:
# File '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/data.txt' has been deleted.

# %%
# remove empty directory
folder_name = '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/old_folder'

if os.path.exists(folder_name):
    os.rmdir(folder_name)
    print(f"Folder '{folder_name}' has been deleted.")
else:
    print(f"Folder '{folder_name}' does not exist.")
# Out:
# Folder '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/Data_Files' has been deleted.

# %%
old_name = "new_data"
new_name = "renamed_data"

path = '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/new_data'

if os.path.exists(old_name):
    os.rename(old_name, new_name)
    print(f"Renamed '{old_name}' to '{new_name}'.")
else:
    print(f"'{old_name}' does not exist.")
# Out:
# Renamed 'new_data' to 'renamed_data'.

# %%
# using join 

folder_path = '/Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/renamed_data'

file_name = 'Data.txt'

full_path =  os.path.join(folder_path , file_name)
print("Full Path:", full_path)
# Out:
# Full Path: /Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/renamed_data/Data.txt

# %%
# check absolute and relative path
relative_path = 'renamed_data/Data.txt'
absolute_path = os.path.abspath(relative_path)
print("Absolute Path:", absolute_path)
# Out:
# Absolute Path: /Users/pankajchouhan/github/Complete-Python-Mastery/00 Lecture/CWPC01/1 Dec 2025/new_data/renamed_data/Data.txt

# %%
get_var = os.environ.get('PATH')
print("HOME Directory:", get_var)
# Out:
# HOME Directory: /usr/local/bin:/Users/pankajchouhan/Library/Python/3.14/bin:/opt/anaconda3/bin:/opt/anaconda3/condabin:/Library/Frameworks/Python.framework/Versions/3.14/bin:/Library/Frameworks/Python.framework/Versions/3.13/bin:/Library/Frameworks/Python.framework/Versions/3.13/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/anaconda3/bin:/opt/anaconda3/condabin:/Library/Frameworks/Python.framework/Versions/3.14/bin:/Library/Frameworks/Python.framework/Versions/3.13/bin:/Library/Frameworks/Python.framework/Versions/3.13/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin

# %%
import sys
print("Python Version:", sys.version)
# Out:
# Python Version: 3.14.0 (v3.14.0:ebf955df7a8, Oct  7 2025, 08:20:14) [Clang 16.0.0 (clang-1600.0.26.6)]

# %%
# command line arguments
print("Command Line Arguments:", sys.argv)

if len(sys.argv) < 2:
   print("No additional command line arguments provided.")
else:
    name = sys.argv[1]
    print(f"Hello, {name}!")
# Out:
# Command Line Arguments: ['/Users/pankajchouhan/Library/Python/3.14/lib/python/site-packages/ipykernel_launcher.py', '--f=/Users/pankajchouhan/Library/Jupyter/runtime/kernel-v305e752c3e3c9591c1e9bd232d22ce1664573e530.json']
# Hello, --f=/Users/pankajchouhan/Library/Jupyter/runtime/kernel-v305e752c3e3c9591c1e9bd232d22ce1664573e530.json!
