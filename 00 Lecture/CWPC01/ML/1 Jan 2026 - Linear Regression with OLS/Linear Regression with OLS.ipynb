# %%
import numpy as np

# %%
# Data
X = np.array([800,1000,1200,1500,1800]) #house size 
y = np.array([180,220,260,300,350]) #prices

# %%
# calculate means
X_mean = np.mean(X)
y_mean = np.mean(y)

# %%
# calculate slope(w) and intercept (b)
w = np.sum((X - X_mean) * (y - y_mean))/ np.sum((X - X_mean)**2)
b = y_mean - w * X_mean

# %%
print(f"Slope (w) {w:6f}")
print(f"Intercept (b) {b:6f}")
# Out:
# Slope (w) 0.166772
# Intercept (b) 51.867089

# %%
predictions = w * X + b
print("predictions",np.round(predictions,2))
# Out:
# predictions [185.28 218.64 251.99 302.03 352.06]

# %%
from sklearn.linear_model import LinearRegression

X = np.array([800,1000,1200,1500,1800]).reshape(-1,1) #house size 
y = np.array([180,220,260,300,350]) #prices

# %%
# create and fit model 
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
print(f"Slope (w) {model.coef_[0]:.6f}")
print(f"Intercept (b) {model.intercept_:6f}")
# Out:
# Slope (w) 0.166772
# Intercept (b) 51.867089

# %%
predictions = model.predict(X)
print("predictions",np.round(predictions,2))
# Out:
# predictions [185.28 218.64 251.99 302.03 352.06]

# %%
# Predict a new house (1300 Sq..)
new_size = np.array([[1300]])
predicted_price = model.predict(new_size)
print(f"predicted price for 1300 = price {predicted_price[0]:.2f}k")
# Out:
# predicted price for 1300 = price 268.67k

# %%
import matplotlib.pyplot as plt

plt.scatter(X,y, color="blue",label="Actual Data")
plt.plot(X,predictions,color="red",linewidth=2,label="best fit line (OLS) ")
plt.xlabel("House Size ")
plt.ylabel("Price")
plt.title("Linear Regression House OLS")
plt.legend()
plt.grid(True)
plt.show()
