# %%
# http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data
# https://archive.ics.uci.edu/static/public/10/data.csv

# %%
import pandas as pd 
url = "https://archive.ics.uci.edu/static/public/10/data.csv"
url2 = "http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df = pd.read_csv(url2)
print(df)
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
# column name 
columns = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
data = pd.read_csv(url2,names=columns,na_values="?",sep=",",skipinitialspace=True)
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
data.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data.shape
# Out:
# (205, 26)

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
data_unique = ['make', 'fuel-type', 'aspiration','num-of-doors', 'body-style', 'drive-wheels', 'engine-location','num-of-cylinders','fuel-system','engine-type']
for col in data_unique:
    print(f'{col} : {data[col].unique()}')
# Out:
# make : ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# fuel-type : ['gas' 'diesel']
# aspiration : ['std' 'turbo']
# num-of-doors : ['two' 'four' nan]
# body-style : ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# drive-wheels : ['rwd' 'fwd' '4wd']
# engine-location : ['front' 'rear']
# num-of-cylinders : ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# fuel-system : ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# engine-type : ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']

# %%
# handel missing values 
data.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
normalized_losses = data['normalized-losses'].mean()
data['normalized-losses'].fillna(normalized_losses,inplace=True)
data['normalized-losses'].head()
# Out:
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_47446/2040312655.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['normalized-losses'].fillna(normalized_losses,inplace=True)
# 0    122.0
# 1    122.0
# 2    122.0
# 3    164.0
# 4    164.0
# Name: normalized-losses, dtype: float64

# %%
# handel missing values 
data.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
price = data['price'].mean()
data['price'].fillna(price,inplace=True)
data['price'].head()

bore = data['bore'].mean()
data['bore'].fillna(bore,inplace=True)
data['bore'].head()
# Out:
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_47446/3914397847.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['price'].fillna(price,inplace=True)
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_47446/3914397847.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# handel missing values 
data.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
horsepower = data['horsepower'].mean()
data['horsepower'].fillna(horsepower,inplace=True)

stroke = data['stroke'].mean()
data['stroke'].fillna(stroke,inplace=True)

peak_rpm = data['peak-rpm'].mean()
data['peak-rpm'].fillna(peak_rpm,inplace=True)
# Out:
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_47446/824717826.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['horsepower'].fillna(horsepower,inplace=True)
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_47446/824717826.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data['num-of-doors'] = data['num-of-doors'].fillna("Unknown")

# %%
data.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.to_csv("auto_mobile.csv")

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          31.681008    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.270844    0.313597
# ...

# %%
# IQR
q1 = data['horsepower'].quantile(0.25)
q3 = data['horsepower'].quantile(0.75)

iqr = q3 - q1
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

outliner = data[(data['horsepower'] < lower) | (data['horsepower'] > upper)]
print(outliner[['make','horsepower']].head())
print(upper)
print(lower)
print(iqr)
# Out:
#         make  horsepower
# 49    jaguar       262.0
# 105   nissan       200.0
# 126  porsche       207.0
# 127  porsche       207.0
# 128  porsche       207.0
# 185.0
# 1.0
# 46.0

# %%
# % pip install scipy
from scipy import stats
import numpy as np

data['zscore'] = stats.zscore(data['horsepower'])
z_outliners = data[np.abs(data['zscore']) > 3]
print(z_outliners[['make','horsepower']].head())
# Out:
#         make  horsepower
# 49    jaguar       262.0
# 129  porsche       288.0

# %%
# Encoding Categorical data
print(data.columns)
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'zscore'],
#       dtype='object')

# %%
data['num-of-doors'].head()
# Out:
# 0     two
# 1     two
# 2     two
# 3    four
# 4    four
# Name: num-of-doors, dtype: object

# %%
data_unique = ['num-of-doors']
for col in data_unique:
    print(f'{col} : {data[col].unique()}')
# Out:
# num-of-doors : ['two' 'four' 'Unknown']

# %%
# label Encoding One Hot
cyl_map = {'two':2,'four':4,'Unknown':0}
data['num-of-doors_int'] = data['num-of-doors'].map(cyl_map)
#data[['num-of-doors','num-of-doors_int']].head() 
data[['num-of-doors','num-of-doors_int']].tail()
# Out:
#     num-of-doors  num-of-doors_int
# 200         four                 4
# 201         four                 4
# 202         four                 4
# 203         four                 4
# 204         four                 4

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder , OneHotEncoder , StandardScaler , MinMaxScaler

# %%
# boxplot ..  Visualization 
plt.figure(figsize=(6,4))
sns.boxplot(x=data["price"])
plt.title("Price outlier Detection")
plt.show()

# %%
# handling skewness 

# check skewness 
data["price"].skew()
# Out:
# np.float64(1.8273241596359218)

# %%
# apply log Transformation
data["price_log"] = np.log(data['price'])
data['price_log']
# Out:
# 0       9.510075
# 1       9.711116
# 2       9.711116
# 3       9.543235
# 4       9.767095
#          ...
# 200     9.731809
# 201     9.854560
# 202     9.975110
# 203    10.019936
# 204    10.026811
# Name: price_log, Length: 205, dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.histplot(data['price'],kde=True)
plt.title("Origial Price")
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.histplot(data["price_log"],kde=True)
plt.title("Log Transformend Price")
plt.show()

# %%
# data encoding 
# label encoding (Binary categories)
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    stroke  compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  \
# ...

# %%
data_unique = ['fuel-type']
for col in data_unique:
    print(f'{col} : {data[col].unique()}')
# Out:
# fuel-type : ['gas' 'diesel']

# %%
data_unique = ['aspiration']
for col in data_unique:
    print(f'{col} : {data[col].unique()}')
# Out:
# aspiration : ['std' 'turbo']

# %%
le = LabelEncoder()

data['fuel-type'] = le.fit_transform(data['fuel-type'])
data['aspiration'] = le.fit_transform(data['aspiration'])

# %%
data.head()
# Out:
#    symboling  normalized-losses         make  fuel-type  aspiration  \
# 0          3              122.0  alfa-romero          1           0
# 1          3              122.0  alfa-romero          1           0
# 2          1              122.0  alfa-romero          1           0
# 3          2              164.0         audi          1           0
# 4          2              164.0         audi          1           0
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    stroke  compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  \
# ...

# %%
data_unique = ['aspiration']
for col in data_unique:
    print(f'{col} : {data[col].unique()}')
# Out:
# aspiration : [0 1]

# %%
# label Encoding (Ordinal Encoding)
cyl_map = {'two':2,'four':4,'Unknown':0}
data['num-of-doors_int'] = data['num-of-doors'].map(cyl_map)
#data[['num-of-doors','num-of-doors_int']].head() 
data[['num-of-doors','num-of-doors_int']].tail()

# %%
# One Hot Encoding

data = pd.get_dummies(
    data,
    columns = ['body-style','drive-wheels','engine-location',''],
    drop_first=True
)

# %%
data.head()
# Out:
#    symboling  normalized-losses         make  fuel-type  aspiration  \
# 0          3              122.0  alfa-romero          1           0
# 1          3              122.0  alfa-romero          1           0
# 2          1              122.0  alfa-romero          1           0
# 3          2              164.0         audi          1           0
# 4          2              164.0         audi          1           0
#
#   num-of-doors  wheel-base  length  width  height  ...    zscore  \
# 0          two        88.6   168.8   64.1    48.8  ...  0.171065
# 1          two        88.6   168.8   64.1    48.8  ...  0.171065
# 2          two        94.5   171.2   65.5    52.4  ...  1.261807
# 3         four        99.8   176.6   66.2    54.3  ... -0.057230
# 4         four        99.4   176.6   66.4    54.3  ...  0.272529
#
#   num-of-doors_int price_log  body-style_hardtop body-style_hatchback  \
# 0                2  9.510075               False                False
# ...

# %%
data_unique = ['make']
for col in data_unique:
    print(f'{col} : {data[col].unique()}')
# Out:
# make : ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']

# %%
data.columns.tolist()
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price',
#  'zscore',
#  'num-of-doors_int',
#  'price_log',
#  'body-style_hardtop',
#  'body-style_hatchback',
#  'body-style_sedan',
#  'body-style_wagon',
#  'drive-wheels_fwd',
#  'drive-wheels_rwd',
#  'engine-location_rear']

# %%
# check columns data 
data[['curb-weight','engine-size']].head()
# Out:
#    curb-weight  engine-size
# 0         2548          130
# 1         2548          130
# 2         2823          152
# 3         2337          109
# 4         2824          136

# %%
# feature Scaling 
# Standardization (Z-score)



scaler = StandardScaler()
scale_cols = ['wheel-base','length','width','height','curb-weight','engine-size']
data['scale_cols'] = scaler.fit_transform(data[scale_cols])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scale_cols'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
