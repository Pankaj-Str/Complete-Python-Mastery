# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# %%
X = np.array(
    [201,150], # samsung A14
    [206,999], # iphone
    [188,200], # Xiaomi
    [197,599] # google pixel
)
