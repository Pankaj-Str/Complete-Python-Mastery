# %%
import pandas as pd

# %%
# Load the dataset into a Pandas DataFrame and display the first 5 rows.
# read dataset csv
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Transaction_ID  Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0        100000.0         4452       2023-01-01           Online  Walmart
# 1        100001.0         2775       2023-01-01              ATM  BestBuy
# 2        100002.0         2259       2023-01-01   Mobile Payment     Uber
# 3        100003.0         4545       2023-01-01           Online  BestBuy
# 4        100004.0         2137       2023-01-01              ATM   Amazon
#
#    Category   Amount Payment_Mode Transaction_Status       Location
# 0    Travel  4520.70   Debit Card           Approved      Jonesport
# 1    Travel  1437.85   Debit Card           Approved  Port Jennifer
# 2  Clothing  3320.52       PayPal           Approved     Port James
# 3    Travel  2659.96   Debit Card           Approved     Hawkinston
# 4    Travel  2517.07   Debit Card           Approved    Matthewland

# %%
# Check the shape, column names, and summary statistics of the dataset.
print(df.shape)
print(df.describe()) # only int value
# Out:
# (5500, 10)
#        Transaction_ID  Customer_ID       Amount
# count     5499.000000  5500.000000  5498.000000
# mean    102749.998727  2989.954182  2492.286513
# std       1587.571099  1153.928878  1444.710273
# min     100000.000000  1000.000000     6.550000
# 25%     101375.500000  1988.000000  1236.765000
# 50%     102750.000000  3000.000000  2503.355000
# 75%     104124.500000  3990.000000  3768.332500
# max     105499.000000  4998.000000  4997.490000

# %%
# print columns name 
print(df.columns.tolist())
# Out:
# ['Transaction_ID', 'Customer_ID', 'Transaction_Date', 'Transaction_Type', 'Merchant', 'Category', 'Amount', 'Payment_Mode', 'Transaction_Status', 'Location']

# %%
# Identify and handle missing values (fill or drop based on the data type).
print(df.isnull().sum())
# Out:
# Transaction_ID        1
# Customer_ID           0
# Transaction_Date      0
# Transaction_Type      0
# Merchant              0
# Category              4
# Amount                2
# Payment_Mode          0
# Transaction_Status    0
# Location              0
# dtype: int64

# %%
# handel missing value
print(df.dtypes)
# Out:
# Transaction_ID        float64
# Customer_ID             int64
# Transaction_Date       object
# Transaction_Type       object
# Merchant               object
# Category               object
# Amount                float64
# Payment_Mode           object
# Transaction_Status     object
# Location               object
# dtype: object

# %%
num_cols = ['Customer_ID','Amount','Transaction_ID']
categorical_col = ['Transaction_Type','Merchant','Category','Payment_Mode','Transaction_Status','Location']

for col in num_cols:
    if df[col].isnull().any():
        df[col].fillna(df[col].mean(),inplace=True)
# Out:
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_88562/2553845451.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(),inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Transaction_ID        0
# Customer_ID           0
# Transaction_Date      0
# Transaction_Type      0
# Merchant              0
# Category              4
# Amount                0
# Payment_Mode          0
# Transaction_Status    0
# Location              0
# dtype: int64

# %%
for col in categorical_col:
    if df[col].isnull().any():
        df[col].fillna("unknown",inplace=True)
# Out:
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_88562/3443848894.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("unknown",inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Transaction_ID        0
# Customer_ID           0
# Transaction_Date      0
# Transaction_Type      0
# Merchant              0
# Category              0
# Amount                0
# Payment_Mode          0
# Transaction_Status    0
# Location              0
# dtype: int64

# %%
# delete row missing value > 50%
df = df.dropna(thresh=len(df)*0.5,axis=1)

# %%
df.dtypes
# Out:
# Transaction_ID        float64
# Customer_ID             int64
# Transaction_Date       object
# Transaction_Type       object
# Merchant               object
# Category               object
# Amount                float64
# Payment_Mode           object
# Transaction_Status     object
# Location               object
# dtype: object

# %%
# Convert Transaction_Date into datetime format and extract year, month, and day as new columns.
# convert date 
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])

# %%
df.dtypes
# Out:
# Transaction_ID               float64
# Customer_ID                    int64
# Transaction_Date      datetime64[ns]
# Transaction_Type              object
# Merchant                      object
# Category                      object
# Amount                       float64
# Payment_Mode                  object
# Transaction_Status            object
# Location                      object
# dtype: object

# %%
# year , month , day
df['Year'] = df['Transaction_Date'].dt.year
df['Month'] = df['Transaction_Date'].dt.month
df['Day'] = df['Transaction_Date'].dt.day

# %%
df.head()
# Out:
#    Transaction_ID  Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0        100000.0         4452       2023-01-01           Online  Walmart
# 1        100001.0         2775       2023-01-01              ATM  BestBuy
# 2        100002.0         2259       2023-01-01   Mobile Payment     Uber
# 3        100003.0         4545       2023-01-01           Online  BestBuy
# 4        100004.0         2137       2023-01-01              ATM   Amazon
#
#    Category   Amount Payment_Mode Transaction_Status       Location  Year  \
# 0    Travel  4520.70   Debit Card           Approved      Jonesport  2023
# 1    Travel  1437.85   Debit Card           Approved  Port Jennifer  2023
# 2  Clothing  3320.52       PayPal           Approved     Port James  2023
# 3    Travel  2659.96   Debit Card           Approved     Hawkinston  2023
# 4    Travel  2517.07   Debit Card           Approved    Matthewland  2023
#
#    Month  Day
# 0      1    1
# 1      1    1
# 2      1    1
# 3      1    1
# 4      1    1

# %%
# Retrieve all transactions made in January 2024.
jan_2023_transactions = df[(df['Year']== 2023) & (df['Month'] == 1)]
print(jan_2023_transactions)
jan_2023_transactions.to_csv("jan_2023_transactions.csv")
# Out:
#      Transaction_ID  Customer_ID Transaction_Date Transaction_Type  \
# 0          100000.0         4452       2023-01-01           Online
# 1          100001.0         2775       2023-01-01              ATM
# 2          100002.0         2259       2023-01-01   Mobile Payment
# 3          100003.0         4545       2023-01-01           Online
# 4          100004.0         2137       2023-01-01              ATM
# ..              ...          ...              ...              ...
# 739        100739.0         3898       2023-01-31              POS
# 740        100740.0         2457       2023-01-31   Mobile Payment
# 741        100741.0         2107       2023-01-31   Mobile Payment
# 742        100742.0         2678       2023-01-31              POS
# 743        100743.0         4586       2023-01-31              ATM
#
#         Merchant     Category   Amount Payment_Mode Transaction_Status  \
# 0        Walmart       Travel  4520.70   Debit Card           Approved
# 1        BestBuy       Travel  1437.85   Debit Card           Approved
# 2           Uber     Clothing  3320.52       PayPal           Approved
# 3        BestBuy       Travel  2659.96   Debit Card           Approved
# 4         Amazon       Travel  2517.07   Debit Card           Approved
# ..           ...          ...      ...          ...                ...
# 739      BestBuy    Groceries  2579.83       PayPal           Approved
# 740         Uber  Electronics   399.85       PayPal           Approved
# 741      BestBuy     Clothing  1455.49   Debit Card            Pending
# 742      Walmart    Groceries   781.63          UPI           Approved
# 743  Apple Store     Clothing  1697.28          UPI           Approved
#
#           Location  Year  Month  Day
# 0        Jonesport  2023      1    1
# 1    Port Jennifer  2023      1    1
# 2       Port James  2023      1    1
# 3       Hawkinston  2023      1    1
# 4      Matthewland  2023      1    1
# ..             ...   ...    ...  ...
# 739    East Amanda  2023      1   31
# 740      Grossfurt  2023      1   31
# 741   Port Charles  2023      1   31
# 742    Heathertown  2023      1   31
# 743    East Nathan  2023      1   31
#
# [744 rows x 13 columns]

# %%
# Find transactions where Amount > 4000 and Transaction_Type is "Online".
high_online_transactions = df[(df['Amount'] > 4000) & (df['Transaction_Type']== "Online")]
print(high_online_transactions)
# Out:
#       Transaction_ID  Customer_ID Transaction_Date Transaction_Type  \
# 0           100000.0         4452       2023-01-01           Online
# 22          100022.0         3057       2023-01-01           Online
# 26          100026.0         4254       2023-01-02           Online
# 27          100027.0         1719       2023-01-02           Online
# 34          100034.0         2424       2023-01-02           Online
# ...              ...          ...              ...              ...
# 5326        105326.0         1662       2023-08-10           Online
# 5341        105341.0         2011       2023-08-11           Online
# 5395        105395.0         3551       2023-08-13           Online
# 5446        105446.0         4468       2023-08-15           Online
# 5461        105461.0         1140       2023-08-16           Online
#
#          Merchant       Category   Amount Payment_Mode Transaction_Status  \
# 0         Walmart         Travel  4520.70   Debit Card           Approved
# 22        BestBuy      Groceries  4094.49       PayPal           Approved
# 26        BestBuy         Travel  4054.78  Credit Card           Approved
# 27        Walmart  Entertainment  4471.68          UPI            Pending
# 34         Target      Groceries  4074.73       PayPal           Approved
# ...           ...            ...      ...          ...                ...
# 5326       Target    Electronics  4020.44  Credit Card           Approved
# 5341  Apple Store         Dining  4532.78  Credit Card           Approved
# 5395       Target         Dining  4540.80  Credit Card            Pending
# 5446      Walmart         Dining  4124.70  Credit Card           Declined
# 5461  Apple Store  Entertainment  4027.18       PayPal           Approved
#
#                 Location  Year  Month  Day
# 0              Jonesport  2023      1    1
# 22          West Kenneth  2023      1    1
# 26          Stevensmouth  2023      1    2
# 27           Riveramouth  2023      1    2
# 34        North Marytown  2023      1    2
# ...                  ...   ...    ...  ...
# 5326  South Adrianaburgh  2023      8   10
# 5341           Allenland  2023      8   11
# 5395          Floresview  2023      8   13
# 5446         Cartermouth  2023      8   15
# 5461   South Lorichester  2023      8   16
#
# [291 rows x 13 columns]

# %%
# Select only Approved transactions from the dataset.
df.head()
# Out:
#    Transaction_ID  Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0        100000.0         4452       2023-01-01           Online  Walmart
# 1        100001.0         2775       2023-01-01              ATM  BestBuy
# 2        100002.0         2259       2023-01-01   Mobile Payment     Uber
# 3        100003.0         4545       2023-01-01           Online  BestBuy
# 4        100004.0         2137       2023-01-01              ATM   Amazon
#
#    Category   Amount Payment_Mode Transaction_Status       Location  Year  \
# 0    Travel  4520.70   Debit Card           Approved      Jonesport  2023
# 1    Travel  1437.85   Debit Card           Approved  Port Jennifer  2023
# 2  Clothing  3320.52       PayPal           Approved     Port James  2023
# 3    Travel  2659.96   Debit Card           Approved     Hawkinston  2023
# 4    Travel  2517.07   Debit Card           Approved    Matthewland  2023
#
#    Month  Day
# 0      1    1
# 1      1    1
# 2      1    1
# 3      1    1
# 4      1    1

# %%
approved_transactions = df[df['Transaction_Status']=='Approved']
print(approved_transactions)
# Out:
#       Transaction_ID  Customer_ID Transaction_Date Transaction_Type  \
# 0           100000.0         4452       2023-01-01           Online
# 1           100001.0         2775       2023-01-01              ATM
# 2           100002.0         2259       2023-01-01   Mobile Payment
# 3           100003.0         4545       2023-01-01           Online
# 4           100004.0         2137       2023-01-01              ATM
# ...              ...          ...              ...              ...
# 5495        105495.0         3262       2023-08-17              ATM
# 5496        105496.0         1234       2023-08-18              POS
# 5497        105497.0         3978       2023-08-18           Online
# 5498        105498.0         3082       2023-08-18              ATM
# 5499        105499.0         2271       2023-08-18   Mobile Payment
#
#          Merchant       Category   Amount Payment_Mode Transaction_Status  \
# 0         Walmart         Travel  4520.70   Debit Card           Approved
# 1         BestBuy         Travel  1437.85   Debit Card           Approved
# 2            Uber       Clothing  3320.52       PayPal           Approved
# 3         BestBuy         Travel  2659.96   Debit Card           Approved
# 4          Amazon         Travel  2517.07   Debit Card           Approved
# ...           ...            ...      ...          ...                ...
# 5495  Apple Store         Travel  4554.82   Debit Card           Approved
# 5496         Uber         Travel  4118.51   Debit Card           Approved
# 5497  Apple Store       Clothing  2981.13          UPI           Approved
# 5498         Uber       Clothing  2168.39   Debit Card           Approved
# 5499      Netflix  Entertainment  1918.66          UPI           Approved
#
#                Location  Year  Month  Day
# 0             Jonesport  2023      1    1
# 1         Port Jennifer  2023      1    1
# 2            Port James  2023      1    1
# 3            Hawkinston  2023      1    1
# 4           Matthewland  2023      1    1
# ...                 ...   ...    ...  ...
# 5495   South Hannahtown  2023      8   17
# 5496     South Courtney  2023      8   18
# 5497           Rubenton  2023      8   18
# 5498     East Brianfurt  2023      8   18
# 5499  New Stephaniebury  2023      8   18
#
# [4698 rows x 13 columns]

# %%
# Data Manipulation and Feature (Column) Engineering
# Create a new column Discounted_Amount, assuming a 5% discount on all transactions above $4000.

df['Discounted_Amount'] = df['Amount'].apply(lambda x : x * 0.95 if x > 4000 else x)
# Out:
# 0       4294.6650
# 1       1437.8500
# 2       3320.5200
# 3       2659.9600
# 4       2517.0700
#           ...
# 5495    4327.0790
# 5496    3912.5845
# 5497    2981.1300
# 5498    2168.3900
# 5499    1918.6600
# Name: Discounted_Amount, Length: 5500, dtype: float64

# %%
# Categorize the Transaction_Amount into Low, Medium, and High based on:
# Low: Below $1000
# Medium: Between $1000 - $5000=4000
# High: Above $4000

def categorize_amount(amount):
    if amount < 1000:
        return "Low"
    elif 1000 <= amount <= 4000:
        return "Medium"
    else:
        return 'High'

df['Amount_Category'] = df['Amount'].apply(categorize_amount)

# %%
df.head(10)
# Out:
#    Transaction_ID  Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0   100000.000000         4452       2023-01-01           Online  Walmart
# 1   100001.000000         2775       2023-01-01              ATM  BestBuy
# 2   100002.000000         2259       2023-01-01   Mobile Payment     Uber
# 3   100003.000000         4545       2023-01-01           Online  BestBuy
# 4   100004.000000         2137       2023-01-01              ATM   Amazon
# 5   100005.000000         4096       2023-01-01              ATM     Uber
# 6   100006.000000         1587       2023-01-01           Online  Netflix
# 7   102749.998727         2103       2023-01-01              ATM     Uber
# 8   100008.000000         3553       2023-01-01              POS   Amazon
# 9   100009.000000         4821       2023-01-01   Mobile Payment  Netflix
#
#         Category   Amount Payment_Mode Transaction_Status            Location  \
# 0         Travel  4520.70   Debit Card           Approved           Jonesport
# 1         Travel  1437.85   Debit Card           Approved       Port Jennifer
# 2       Clothing  3320.52       PayPal           Approved          Port James
# 3         Travel  2659.96   Debit Card           Approved          Hawkinston
# 4         Travel  2517.07   Debit Card           Approved         Matthewland
# 5      Groceries  2032.91          UPI           Approved  West Patriciamouth
# 6  Entertainment  2309.06   Debit Card           Approved           Scottport
# 7         Dining   334.82       PayPal            Pending            Shawview
# 8         Dining   374.29       PayPal           Approved        Port Lindsay
# 9    Electronics  1117.12          UPI           Approved      Lake Steveport
#
#    Year  Month  Day  Discounted_Amount Amount_Category
# 0  2023      1    1           4294.665            High
# 1  2023      1    1           1437.850          Medium
# 2  2023      1    1           3320.520          Medium
# 3  2023      1    1           2659.960          Medium
# 4  2023      1    1           2517.070          Medium
# 5  2023      1    1           2032.910          Medium
# 6  2023      1    1           2309.060          Medium
# 7  2023      1    1            334.820             Low
# 8  2023      1    1            374.290             Low
# 9  2023      1    1           1117.120          Medium

# %%
# Drop the Merchant column if more than 30% of values are missing.
if df['Merchant'].isnull().sum()/len(df) > 0.3:
    df.drop('Merchant',axis=1,inplace=True)

# %%
# Aggregation and Insights
# Find the total transaction amount per Category.
total_per_category = df.groupby('Category')['Amount'].sum().reset_index()
print(total_per_category)
# Out:
#         Category        Amount
# 0       Clothing  2.182564e+06
# 1         Dining  2.402259e+06
# 2    Electronics  2.320286e+06
# 3  Entertainment  2.241827e+06
# 4      Groceries  2.383573e+06
# 5         Travel  2.165420e+06
# 6        unknown  1.164752e+04

# %%
# Determine the number of declined transactions per Payment_Mode.
decliend_per_mode = df[df['Transaction_Status'] == 'Declined'].groupby('Payment_Mode').size().reset_index(name="Count")

# %%
print(decliend_per_mode)
# Out:
#   Payment_Mode  Count
# 0  Credit Card    117
# 1   Debit Card    145
# 2       PayPal    135
# 3          UPI    134

# %%
# Identify the top 5 most frequent merchants based on transaction count.
top_merchants = df['Merchant'].value_counts().head(5).reset_index(name="Count")
print(top_merchants)
# Out:
#   Merchant  Count
# 0     Uber    833
# 1  Walmart    818
# 2  BestBuy    790
# 3  Netflix    774
# 4   Amazon    770

# %%
# Find the average transaction amount per Location.
avg_per_location = df.groupby("Location")["Amount"].mean().reset_index(name="Average_Amount")
print(avg_per_location)
# Out:
#           Location  Average_Amount
# 0        Aaronfort        2429.860
# 1       Aaronmouth        2648.060
# 2        Aaronside         315.540
# 3       Abbottbury        1549.850
# 4      Abigailfort        3634.880
# ...            ...             ...
# 4658  Zacharyburgh        2430.690
# 4659  Zacharyhaven         830.360
# 4660  Zacharymouth        3508.690
# 4661   Zacharystad        2925.135
# 4662   Zavalaburgh         364.530
#
# [4663 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Transaction_Date', 'Transaction_Type',
#        'Merchant', 'Category', 'Amount', 'Payment_Mode', 'Transaction_Status',
#        'Location', 'Year', 'Month', 'Day', 'Discounted_Amount',
#        'Amount_Category'],
#       dtype='object')

# %%
# Fraud Detection Indicators
# Find customers who made more than 10 transactions in a single day (potential fraud).
df['Date'] = df['Transaction_Date'].dt.date
transactions_per_day = df.groupby(['Customer_ID','Date']).size().reset_index(name='Transcation_count')
potential_fraud_customer = transactions_per_day[transactions_per_day['Transcation_count']>1]
potential_fraud_customer
# Out:
#       Customer_ID        Date  Transcation_count
# 114          1079  2023-06-04                  2
# 203          1140  2023-08-16                  2
# 494          1343  2023-08-16                  2
# 1017         1709  2023-07-10                  2
# 1084         1776  2023-04-18                  2
# 1274         1910  2023-01-09                  2
# 1337         1956  2023-04-20                  2
# 1544         2122  2023-07-09                  2
# 1565         2136  2023-03-01                  2
# 1600         2165  2023-07-10                  2
# 1753         2270  2023-05-25                  2
# 2578         2884  2023-02-01                  2
# 2905         3131  2023-04-15                  2
# 3057         3234  2023-04-23                  2
# 3233         3351  2023-07-25                  2
# 3807         3783  2023-03-18                  2
# 3916         3861  2023-05-27                  2
# 4323         4143  2023-03-23                  2
# 4458         4238  2023-02-13                  2
# 4732         4429  2023-05-17                  2
# 5381         4916  2023-08-12                  2

# %%
# Identify transactions that have the same Customer_ID but occurred in different locations within 5 minutes.

# %%
