# %%
import numpy as np

x = np.array([1,2,3],dtype=float)
y = np.array([2,4,6],dtype=float)

w = 0.0

learning_rate = 0.01

for epoch in range(10):
  # prediction
  y_pred = w * x

  # loss
  loss = np.mean((y_pred - y)**2)

  # gradient
  gradient = np.mean(2 * x * (y_pred - y))

  # weight update
  w = w - learning_rate * gradient

  print(f'Epoch {epoch+1}: Loss = {loss}, Weight = {w}')
# Out:
# Epoch 1: Loss = 18.666666666666668, Weight = 0.18666666666666668
# Epoch 2: Loss = 15.344829629629627, Weight = 0.3559111111111111
# Epoch 3: Loss = 12.614131947983543, Weight = 0.5093594074074075
# Epoch 4: Loss = 10.369377089329044, Weight = 0.6484858627160495
# Epoch 5: Loss = 8.524088828632445, Weight = 0.7746271821958848
# Epoch 6: Loss = 7.007179865528254, Weight = 0.8889953118576022
# Epoch 7: Loss = 5.760213279680471, Weight = 0.9926890827508926
# Epoch 8: Loss = 4.735151325376444, Weight = 1.0867047683608093
# Epoch 9: Loss = 3.8925048406294542, Weight = 1.1719456566471338
# Epoch 10: Loss = 3.19981197921255, Weight = 1.2492307286934012

# %%
# deep learning
import tensorflow as tf
import numpy as np

x = np.array([1,2,3],dtype=float)
y = np.array([2,4,6],dtype=float)

# neural network
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1,input_shape=(1,))
])

# compile
model.compile(optimizer='sgd',loss='mean_squared_error')

# train

model.fit(x,y,epochs=10)

# prediction
prediction = model.predict(np.array([6.0]))

print("prediction ",prediction)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 38.2756
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 30.2876
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 23.9733
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 18.9820
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 15.0365
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 11.9177
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 9.4522
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 7.5033
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 5.9626
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4.7446
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# prediction  [[5.542251]]
