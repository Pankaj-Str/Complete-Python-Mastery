# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data.csv')
print(data.head()) # top 5 rows of the dataset
# Out:
#        Date      Open      High       Low     Close
# 0  01/19/24  37572.50  37933.73  37451.71  37863.80
# 1  01/18/24  37300.81  37522.29  37122.95  37468.61
# 2  01/17/24  37281.86  37371.66  37132.89  37266.67
# 3  01/16/24  37493.54  37543.18  37201.39  37361.12
# 4  01/12/24  37818.05  37825.27  37470.19  37592.98

# %%
# check column names and data types
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    61 non-null     object
#  1    Open   61 non-null     float64
#  2    High   61 non-null     float64
#  3    Low    61 non-null     float64
#  4    Close  61 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.5+ KB
# None

# %%
# check column names
data.columns
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close'], dtype='object')

# %%
# rename columns for easier access
data = data.rename(
    columns={
        ' Open': 'Open', 
        ' High': 'High', 
        ' Low': 'Low', 
        ' Close': 'Close', 
})

# %%
# check column name again
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# convert 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# /var/folders/f3/3kqpjfqj03s00nxsf6rppv280000gn/T/ipykernel_98104/879321794.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])

# %%
# create a line plot of 'Close' price over time
plt.figure(figsize=(10, 5))
plt.plot(data['Date'], data['Close'], label='Close Price')
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()

# %%
# create a line plot of 'Open' price over time
plt.figure(figsize=(10, 5))
plt.plot(data['Date'], data['Open'], label='Close Price')
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(data['Date'], data['Open'], label='Close Price')
plt.plot(data['Date'], data['Close'], label='Close Price')
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()

# %%
# bar plot of 'Close' price by month
data['Month'] = data['Date'].dt.month # find the month from the 'Date' column
monthly_close = data.groupby('Month')['Close'].mean()
plt.figure(figsize=(10, 5))
monthly_close.plot(kind='bar')
plt.title('Average Close Price by Month')
plt.xlabel('Month')
plt.ylabel('Average Close Price')
plt.grid()
plt.show()
