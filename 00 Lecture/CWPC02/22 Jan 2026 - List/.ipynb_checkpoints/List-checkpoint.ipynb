# %%
# create a list 
number = [12,23,24,25,56]
print(number)
# Out:
# [12, 23, 24, 25, 56]

# %%
# str list 
names = ['Nishant','Joy','Neha']
print(names)
# Out:
# ['Nishant', 'Joy', 'Neha']

# %%
# mixed 
data = [1,2,'python',5.6,True]
print(data)
# Out:
# [1, 2, 'python', 5.6, True]

# %%
data = [12,23,24,25,56]
# access data from list 
print(data[2])
# Out:
# 24

# %%
# Slicing data 
print(data[2:4])
print(data[:4])
# Out:
# [24, 25]
