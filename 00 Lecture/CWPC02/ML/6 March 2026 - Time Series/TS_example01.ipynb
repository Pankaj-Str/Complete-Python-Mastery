# %%
# install packages
# %pip install yfinance
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# import lib
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# download stock data 
data = yf.download('GOOG', start='2020-01-01', end='2023-12-31')
data.head() # print top 5 rows
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           GOOG       GOOG       GOOG       GOOG      GOOG
# Date
# 2020-01-02  67.859543  67.897754  66.578153  66.578153  28132000
# 2020-01-03  67.526543  68.114139  66.776371  66.891308  23728000
# 2020-01-06  69.191559  69.305201  66.997512  66.997512  34646000
# 2020-01-07  69.148361  69.627267  69.001460  69.376652  30054000
# 2020-01-08  69.693291  70.053587  69.024305  69.085840  30560000

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Close'], label='AAPL Close Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.title('Apple Inc. Stock Price (2020-2023)')
plt.legend()
plt.grid()
plt.show()

# %%
# moving average (Trend Detection)

data["MA50"] = data["Close"].rolling(window=50).mean()
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['MA50'], label='50-Day MA', color='orange')
plt.plot(data.index, data['Close'], label='AAPL Close Price', color='blue')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.title('Apple Inc. Stock Price with 50-Day Moving Average')
plt.legend()
plt.grid()
plt.show()
