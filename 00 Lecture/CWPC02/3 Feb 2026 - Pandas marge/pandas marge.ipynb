# %%
import pandas as pd 

# create a  table 1 

students = pd.DataFrame({
    'student_id': [1, 2, 3, 4],
    'name':['Nishant', 'Aarav', 'Diya', 'Rohan'],
    'age':[20, 21, 19, 22]
})

print(students)
# Out:
#    student_id     name  age
# 0           1  Nishant   20
# 1           2    Aarav   21
# 2           3     Diya   19
# 3           4    Rohan   22

# %%
# create a table 2
scores = pd.DataFrame({
    'student_id': [1, 2, 3,7],
    'maths':[85, 90, 78,90],
    'science':[88, 76, 95,80]
})

print(scores)
# Out:
#    student_id  maths  science
# 0           1     85       88
# 1           2     90       76
# 2           3     78       95
# 3           7     90       80

# %%
# merge the two tables on student_id
# step 1: specify the dataframes to merge

merged_data = pd.merge(students, scores, on='student_id')
print('\n marge table inner join \n')
print(merged_data)
# Out:
#  marge table inner join
#
#    student_id     name  age  maths  science
# 0           1  Nishant   20     85       88
# 1           2    Aarav   21     90       76
# 2           3     Diya   19     78       95

# %%
# 1 left join
left_joined_data = pd.merge(students, scores, on='student_id', how='left')
print('\n left join \n')
print(left_joined_data)
# Out:
#  left join
#
#    student_id     name  age  maths  science
# 0           1  Nishant   20   85.0     88.0
# 1           2    Aarav   21   90.0     76.0
# 2           3     Diya   19   78.0     95.0
# 3           4    Rohan   22    NaN      NaN

# %%
# 2 right join
right_joined_data = pd.merge(students, scores, on='student_id', how='right')
print('\n right join \n')
print(right_joined_data)
# Out:
#  right join
#
#    student_id     name   age  maths  science
# 0           1  Nishant  20.0     85       88
# 1           2    Aarav  21.0     90       76
# 2           3     Diya  19.0     78       95
# 3           7      NaN   NaN     90       80

# %%
# outer join  print all data 
outer_joined_data = pd.merge(students, scores, on='student_id', how='outer')
print('\n right join \n')
print(outer_joined_data)
# Out:
#  right join
#
#    student_id     name   age  maths  science
# 0           1  Nishant  20.0   85.0     88.0
# 1           2    Aarav  21.0   90.0     76.0
# 2           3     Diya  19.0   78.0     95.0
# 3           4    Rohan  22.0    NaN      NaN
# 4           7      NaN   NaN   90.0     80.0

# %%
# example different column name
# create a  table 3
teachers = pd.DataFrame({
    'teacher_id': [1, 2, 3],
    'name':['Mr. Sharma', 'Ms. Gupta', 'Mrs. Singh'],
    'subject':['Maths', 'Science', 'English']
})

print(teachers)
# Out:
#    teacher_id        name  subject
# 0           1  Mr. Sharma    Maths
# 1           2   Ms. Gupta  Science
# 2           3  Mrs. Singh  English

# %%
# left join on different column names
left_joined_diff_col = pd.merge(students, teachers, left_on='name', right_on='name', how='left')
print('\n left join on different column names \n')
print(left_joined_diff_col)
