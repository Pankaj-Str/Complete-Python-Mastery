# %%
# LIST 
data = ["java","c++","python","jsp","R","SQL"]
print(data)

# %%
numbers = [21,22,23,24,25]
print(numbers)

# empty list 
data = []
print(data)

# %%
# check type 
print(type(data))

# %%
#         -6     -5    -4      -3    -2   -1
data = ["java","c++","python","jsp","R","SQL"]
# index    0     1      2      3     4    5

# access single item form list 
print(data[3])
print(data[-1])

# %%
data = [21, 22, 23, 24, 25]
print(data[3])

# %%
data = ["java","c++","python","jsp","R","SQL"]

print(data[2:4])
print(data[1:4])
print(data[3:5])

# %%
# modifying list           
data[2] = "Ruby"
print(data)
