# %%
web = 'www.codeswithpankaj.com'
print(web)
data = "Nishant"
print(data)
# Out:
# www.codeswithpankaj.com
# Nishant

# %%
# Compare Two Strings 
data1 = 'CWPC'
data2 = 'CWPC1'

print(data1 == data2)
print(data1 == "CWPC")
# Out:
# False
# True

# %%
# join String 
firstname = 'Nishant '
lastname = 'jain'
full_name = firstname + lastname
print(full_name)
# Out:
# Nishant jain

# %%
# iterating string 
data = 'cwpc'
for i in data:
    print(i)
# Out:
# c
# w
# p
# c

# %%
# in
print('a' in 'codeswithpankaj')
# not in 
print('a' not in 'codeswithpankaj')
# Out:
# True
# False

# %%
data = 'Codes With Pankaj'
# upper()
print(data.upper())
# lower
print(data.lower())
# partition()
print(data.partition('With'))
# Out:
# CODES WITH PANKAJ
# codes with pankaj
# ('Codes ', 'With', ' Pankaj')

# %%
# replace()
print(data.replace('Pankaj','Python'))
# Out:
# Codes With Python

# %%
# find()
print(data.find('W'))
# Out:
# 6

# %%
# Split()
print(data.split(' '))
# Out:
# ['Codes', 'With', 'Pankaj']

# %%
name = 'Nishant'
age = 34
print('Your Name is ',name,'and Age is ',age)

print('your name is {0} and age {1}'.format(name,age))

print(f'Your Name is {name} and age {age}')
# Out:
# Your Name is  Nishant and Age is  34
# your name is Nishant and age 34
# Your Name is Nishant and age 34
