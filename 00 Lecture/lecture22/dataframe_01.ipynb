# %%
import pandas as pd

# %%
data = {
    'Name':['Rohan','Naresh','Rahul','Aditi','Ganesh'],
    'Age':[23,34,25,16,70],
    'City':['Mumbai','Pune','Jaipur','Bhuj','Surat'],
}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age    City
# 0   Rohan   23  Mumbai
# 1  Naresh   34    Pune
# 2   Rahul   25  Jaipur
# 3   Aditi   16    Bhuj
# 4  Ganesh   70   Surat

# %%
data = [
    ['Rohan','Naresh','Rahul','Aditi','Ganesh'],
    [23,34,25,16,70],
    ['Mumbai','Pune','Jaipur','Bhuj','Surat'],
]

df2 = pd.DataFrame(data)
df2
# Out:
#         0       1       2      3       4
# 0   Rohan  Naresh   Rahul  Aditi  Ganesh
# 1      23      34      25     16      70
# 2  Mumbai    Pune  Jaipur   Bhuj   Surat

# %%
col = ['Student1','Student2','Student3','Student4','Student5']
df3 = pd.DataFrame(data,columns=col)
df3
# Out:
#   Student1 Student2 Student3 Student4 Student5
# 0    Rohan   Naresh    Rahul    Aditi   Ganesh
# 1       23       34       25       16       70
# 2   Mumbai     Pune   Jaipur     Bhuj    Surat

# %%
# export CSV
df3.to_csv('Student_info.csv',index=False)

# %%
# read csv file 
data = pd.read_csv("credit_card_transactions.csv")

# %%
# load top 5 record 
data.head()
# Out:
#   Transaction_ID Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0         100000      4452.0       2023-01-01              NaN  Walmart
# 1         100001      2775.0       2023-01-01              ATM  BestBuy
# 2         100002      2259.0       2023-01-01   Mobile Payment     Uber
# 3         100003      4545.0       2023-01-01           Online  BestBuy
# 4         100004      2137.0       2023-01-01              ATM      NaN
#
#    Category   Amount Payment_Mode Transaction_Status     Location
# 0    Travel  4520.70   Debit Card           Approved    Jonesport
# 1    Travel  1437.85   Debit Card           Approved          NaN
# 2  Clothing  3320.52       PayPal           Approved   Port James
# 3    Travel  2659.96   Debit Card           Approved   Hawkinston
# 4    Travel  2517.07   Debit Card           Approved  Matthewland

# %%
data.head(3)
# Out:
#   Transaction_ID Customer_ID Transaction_Date Transaction_Type Merchant  \
# 0         100000      4452.0       2023-01-01              NaN  Walmart
# 1         100001      2775.0       2023-01-01              ATM  BestBuy
# 2         100002      2259.0       2023-01-01   Mobile Payment     Uber
#
#    Category   Amount Payment_Mode Transaction_Status    Location
# 0    Travel  4520.70   Debit Card           Approved   Jonesport
# 1    Travel  1437.85   Debit Card           Approved         NaN
# 2  Clothing  3320.52       PayPal           Approved  Port James

# %%
# last 5 record
data.tail()
# Out:
#       Transaction_ID Customer_ID Transaction_Date Transaction_Type  \
# 16495      TXN116495   CUST60769       2023-03-11           Online
# 16496      TXN116496   CUST64670       2023-05-10              ATM
# 16497      TXN116497   CUST55544              NaN   Mobile Payment
# 16498      TXN116498   CUST53365       2023-04-11              POS
# 16499      TXN116499   CUST99692       2023-08-17           Online
#
#           Merchant     Category    Amount Payment_Mode Transaction_Status  \
# 16495      BestBuy  Electronics  13681.52          UPI           Approved
# 16496         Uber     Clothing  34951.01       PayPal           Approved
# 16497      Netflix       Travel  26960.87   Debit Card                NaN
# 16498  Apple Store    Groceries  31842.40  Credit Card            Pending
# 16499       Amazon       Travel  21091.60   Debit Card           Approved
#
#                  Location
# 16495          West Kiara
# 16496      West Bruceport
# 16497         Robertmouth
# ...

# %%
# size of data set 
data.shape
# Out:
# (16500, 10)

# %%
# check columns name 
data.columns.to_list()
# Out:
# ['Transaction_ID',
#  'Customer_ID',
#  'Transaction_Date',
#  'Transaction_Type',
#  'Merchant',
#  'Category',
#  'Amount',
#  'Payment_Mode',
#  'Transaction_Status',
#  'Location']

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16500 entries, 0 to 16499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      16500 non-null  str
#  1   Customer_ID         15167 non-null  str
#  2   Transaction_Date    15131 non-null  str
#  3   Transaction_Type    15132 non-null  str
#  4   Merchant            15158 non-null  str
#  5   Category            15144 non-null  str
#  6   Amount              15100 non-null  float64
#  7   Payment_Mode        15184 non-null  str
#  8   Transaction_Status  15128 non-null  str
#  9   Location            15175 non-null  str
# dtypes: float64(1), str(9)
# memory usage: 1.3 MB

# %%
# numeric summary 
data.describe()
# Out:
#              Amount
# count  15100.000000
# mean   16208.393093
# std    15819.878614
# min        6.550000
# 25%     2764.082500
# 50%     8788.420000
# 75%    29613.212500
# max    49998.010000

# %%
data[['Amount','Category','Payment_Mode']].head()
# Out:
#     Amount  Category Payment_Mode
# 0  4520.70    Travel   Debit Card
# 1  1437.85    Travel   Debit Card
# 2  3320.52  Clothing       PayPal
# 3  2659.96    Travel   Debit Card
# 4  2517.07    Travel   Debit Card
