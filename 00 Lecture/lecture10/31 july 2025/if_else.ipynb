# %%
# find the smallest number 
a = 10
b = 2

if a < b:
    print('a is smallest ...')
else:
    print('a is not smallest ...')
# Out:
# a is not smallest ...

# %%
a = 20
b = 30
c = 4

# find the smallest number 
if a < b and a < c:
    print('a is smallest ...')
elif b < a and b < c:
    print('b is smallest ...')
else:
    print('c is smallest ...')
# Out:
# c is smallest ...
